# %%
#standard imports
import pandas as pd
import numpy as np

#API tools
import requests
import json
from pandas.io.json import json_normalize
from urllib.request import Request, urlopen
import json

#visuals
import matplotlib as plt
import seaborn as sns

#Natural Language Processing
import nltk
import lda #Latent Dirichlet Allocation (create topics)
import gensim
from gensim import corpora, models #for constructing document term matrix
from nltk.stem.porter import PorterStemmer
from nltk import stem
from nltk.corpus import stopwords

#magic
# %matplotlib inline

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x) #otherwise we have scientific notation

# %% [markdown]
# # Our Question: Among state and city government open datasets hosted on the Socrata portal, what dataset topics are the most popular as of August 2017?
#
# ## However, this (unfortunately) isn't as easy as choosing a consistent category like "crime and public safety" and adding up views and downloads. We have two obstacles:
# - We need to control for the fact that some datasets just get more views because they are from popular portals. Our goal is determine what *types* of datasets are most popular so all cities and states can use this information. We don't want our conclusion to be that everyone should release data on "New York Lottery" (this is not a joke; our initial analysis found that to be a very popular tag).
# - Datasets themselves vary widely, and not all metadata is standardized or consistent. Some datasets are in broad categories, like annual budget, and some are very niche and specific, like dog licenses. Compounding this challenge is that cities choose all sorts of different tags and categories for similar data;
#
# ### Therefore, we need a way to extract true topics that cut across multiple cities' and states' datasets.
# - We want "budget", "fiscal year" and "expenditures" to all be treated as a single topic.
# - **Fortunately, a machine learning model exists to do just this.** *Latent Dirichlet Allocation* is an algorithm that finds "hidden" topics in a group of documents. It posits that each "document" (in this case, our combined metadata) is a mixture of topics, and that each word in a document is derived from a topic. LDA will produce "topics" composed of words and their expected distribution across that topic. While expected distribution is not very intuitive to interpret, the word combinations in topics is extremely easy to interpret.
#     - **In order to run LDA on this dataset, we processed our metadata by combining "description", "domain_tags" and "categories" attributes into a new attribute called "mash".** Each row of "mash" will be a document in our model.
#         - We excluded dataset name and domain; these are often very specific, parochial tags that will inhibit our efforts to form "topics" that can apply across cities and datasets. As we will see later, proper and parochial names skew our model and we want to avoid them.

# %% [markdown]
# ## Read in a saved dataframe created from Socrata API call on 8.14.17
# - Unpacked JSON dicts returned by API call.
# - Contains data on nearly 30,000 dataset's metadata, including description, topic tags, categories, views, and downloads.
# - **This metadata is not in a standard format**. City and state governments write their own descriptions and choose their own tags. One government may tag their annual budget as "budget", while another may choose "fiscal year", and yet another just "government".
# - **This metadata is often missing one or more attributes**. Some governments don't include a description, or don't include tags.

# %%
big_mash = pd.read_csv('big_mash_archive_8_14.14')

# %%
big_mash.head()
# Out:
#    Unnamed: 0                                     name  \
# 0           0  Homelessness PIT Transitional Age Youth
# 1           1                  Fair Housing Complaints
# 2           2             Parking Complaints Bar Chart
# 3           3                         NVMHI Admissions
# 4           4                Property Owners Trainined
#
#                            description attribution  \
# 0                                   []         NaN
# 1                                   []         NaN
# 2                                   []         NaN
# 3                                   []         NaN
# 4  ['Office', 'of', 'Housing', 'Data']         NaN
#
#                                   columns_field_name  \
# 0  ['location_on_the_night_of_the_count_total_per...
# 1  ['violations', 'percent_found_to_be_compliant'...
# 2  ['percent_of_valid_parking_meter_problem_servi...
# 3  ['lipos_admissions_per_100k', 'nvmhi_admission...
# 4  ['number_of_property_owners_trained', 'percent...
#
#                                         columns_name   type  \
# 0  ['Location on the night of the count, Total Pe...  chart
# 1  ['Number of complaints', 'Percent of sites fou...  chart
# 2  ['Percent of valid parking meter problem servi...  chart
# 3  ['LIPOS Admissions per 100K', 'NVMHI Admission...  chart
# 4  ['Number of property owners trained', 'Percent...  chart
#
#            categories domain_category  \
# 0                  []             NaN
# 1                  []             NaN
# 2  ['transportation']             NaN
# 3                  []             NaN
# 4                  []             NaN
#
#                                        domain_tags provenance  download_count  \
# 0  ['point in time', 'homelessness', 'ss', 'dchs']   official           4.000
# 1                                      ['housing']   official          21.000
# 2                                               []   official          17.000
# 3                               ['delete', 'dchs']   official           5.000
# 4                                      ['housing']   official          11.000
#
#    page_views_last_month  page_views_last_week  page_views_total  \
# 0                 46.000                 2.000           319.000
# 1                 31.000                 0.000           278.000
# 2                 17.000                 2.000           274.000
# 3                 38.000                 1.000           263.000
# 4                 30.000                 0.000           246.000
#
#    page_views_total_log                      domain  \
# 0                 8.322  dashboard.alexandriava.gov
# 1                 8.124  dashboard.alexandriava.gov
# 2                 8.103  dashboard.alexandriava.gov
# 3                 8.044  dashboard.alexandriava.gov
# 4                 7.948  dashboard.alexandriava.gov
#
#                                                 mash  \
# 0  ['point', 'in', 'time', 'homelessness', 'ss', ...
# 1                                        ['housing']
# 2                                 ['transportation']
# 3                                 ['delete', 'dchs']
# 4                                        ['housing']
#
#                                             big_mash
# 0  ['point', 'in', 'time', 'homelessness', 'ss', ...
# 1                                        ['housing']
# 2                                 ['transportation']
# 3                                 ['delete', 'dchs']
# 4     ['housing', 'Office', 'of', 'Housing', 'Data']

# %%
len(big_mash.index)
# Out:
# 21807

# %% [markdown]
# ## Building an LDA Model:
#
# - Running an LDA model is very computationally intensive as explained below; this is why we did it in a separate notebook. Fortunately, we can save and import models.
# - When building an LDA model, we pick the number of topics that we want the algorithm to find. This is a very important parameter.
# - LDA Model fitting is an iterative process. The algorithm starts out by assigning every word to a temporary topic. Then, for *every* word, it updates the topics by calculating:
#     - How prevalent is that word across topics? Topics with a high prevalance of the word in question get a higher weight for that word's assignment.
#      - How prevalent are topics within a document? If one topic within a document is more prevalent, it gets a higher weight.
#      - Based on these two criteria, LDA then updates a word's topic and document assignment.
#      - **An LDA's topic formations get better the more passes you can run. However, running 60 passes of this dataset's model (we do have a large number of documents, although their word count is relatively low) takes about 35 minutes on a MacBook Air with 8GB of RAM.**
#
# ### If we understand nothing else, we need to understand this: LDA is a *probabilistic* model and its results can fluctuate based on small changes in the data and how the model itself randomly assigns topics to begin with!
# - This is a weakness in our analysis; it is not very replicable. It took several different LDA formations to settle on an ideal number of topics and to get consistently coherent topics.
# - Our source data changes based on our API call. Our LDA model changes based upon both the source data and the model's probabilistic results itself. **Thus, for stability and replicability, we've saved both a dataframe and an LDA model. These are snapshots in time, not current, definitive structures.**

# %% [markdown]
# ## Read in saved LDA Model
# - Constructed from 52 topics; 60 passes on the tokens from the "big_mash" column of our dataframe:
# - The source code for this is in the ipynb "Original LDA Code - Socrata API Dataset - Gensim LDA Groupings". **Note that if you run this code yourself (encouraged), you WILL get different results, and perhaps not useful ones**. Finding the right LDA settings for your dataset is time consuming and basically takes trial and error. Again, this is a weakness of our model.

# %%
lda_52_sixty = gensim.models.ldamodel.LdaModel.load('lda_52_sixty_good_model')

# %%
lda_52_sixty.show_topics(num_topics=52, formatted=False)
# Out:
# [(0,
#   [('prevention', 0.039228265770020823),
#    ('hospital', 0.038899194905431915),
#    ('ny', 0.034882850346069173),
#    ('healthy', 0.032344049932466652),
#    ('statewide', 0.029269391777562728),
#    ('hospitals', 0.022294582283033028),
#    ('inpatient', 0.021854135158083089),
#    ('healthcare', 0.018663035226976647),
#    ('api', 0.018299534915519441),
#    ('quality-safety-costs', 0.016526700960621438)]),
#  (1,
#   [('chart', 0.069963659585634108),
#    ('children', 0.059274004768666677),
#    ('income', 0.03908399441304488),
#    ('historic', 0.025093228857131812),
#    ('home', 0.021852521187430106),
#    ('assistance', 0.018091177706023875),
#    ('homes', 0.017940795661987072),
#    ('families', 0.017918354840225928),
#    ('low', 0.017857714487521079),
#    ('pay', 0.017610064270261648)]),
#  (2,
#   [('population', 0.13151520321707977),
#    ('county', 0.091960434049722567),
#    ('demographics', 0.084275005086619365),
#    ('age', 0.0434468663431666),
#    ('total', 0.028221558698175012),
#    ('king', 0.019468810925607257),
#    ('washington', 0.01927613699149228),
#    ('montgomery', 0.018261080011821789),
#    ('number', 0.017900571442482898),
#    ('years', 0.016960472490539676)]),
#  (3,
#   [('transportation', 0.1645420154231319),
#    ('traffic', 0.038249415092180432),
#    ('street', 0.029708854670228657),
#    ('parking', 0.026048447964619643),
#    ('infrastructure', 0.024499661836046696),
#    ('city', 0.024248488006745492),
#    ('safe', 0.023908406994518551),
#    ('vehicle', 0.023135110066475582),
#    ('streets', 0.021985229238776469),
#    ('bike', 0.01551025776156169)]),
#  (4,
#   [('information', 0.045629510720610396),
#    ('tab', 0.02519267217634192),
#    ('projects', 0.024289165547602756),
#    ('concerning', 0.018274567627167695),
#    ('may', 0.017740368430513121),
#    ('contains', 0.017113371818170686),
#    ('project', 0.015854281382776003),
#    ('provided', 0.013839518701256619),
#    ('additional', 0.013692382248742174),
#    ('improvement', 0.012452002727572102)]),
#  (5,
#   [('locations', 0.069775812645793758),
#    ('bacteria', 0.02648594877681025),
#    ('hours', 0.025954898196716671),
#    ('culture', 0.024828275368617661),
#    ('county', 0.023656957609001595),
#    ('levels', 0.02197024161214425),
#    ('contact', 0.02095100106449152),
#    ('directory', 0.019849859557347929),
#    ('e', 0.019300970726415546),
#    ('contains', 0.018603307582784098)]),
#  (6,
#   [('property', 0.13136570965022701),
#    ('consumption', 0.051884459340934608),
#    ('real', 0.046286074447914313),
#    ('value', 0.03077786423134931),
#    ('properties', 0.025283903585934197),
#    ('significant', 0.021787551505509636),
#    ('easy', 0.021674540711116137),
#    ('usage', 0.019934752091226977),
#    ('assessment', 0.019827225768331354),
#    ('company', 0.015464303111405545)]),
#  (7,
#   [('rates', 0.097364682402046362),
#    ('calculated', 0.069242760650261914),
#    ('rate', 0.052423706953771118),
#    ('year', 0.046226566488417858),
#    ('counts', 0.041696995181128169),
#    ('average', 0.026100750207484962),
#    ('seattle', 0.018955865652478202),
#    ('percent', 0.017770826386179429),
#    ('mortality', 0.016407853651273428),
#    ('number', 0.015107387053477006)]),
#  (8,
#   [('health', 0.094596970812741571),
#    ('disease', 0.043755686476799373),
#    ('000', 0.039024957736277545),
#    ('per', 0.030917812190623686),
#    ('rate', 0.029034554086777568),
#    ('rates', 0.026226335228672973),
#    ('chronic', 0.025069794781680706),
#    ('risk', 0.022384318262765962),
#    ('agency', 0.02162102669270825),
#    ('due', 0.0195463066793998)]),
#  (9,
#   [('recreation', 0.13128622968124695),
#    ('parks', 0.064528596736303123),
#    ('jersey', 0.060593984662716933),
#    ('park', 0.040013809141157139),
#    ('center', 0.029877716132019151),
#    ('neighborhoods', 0.0258798720295484),
#    ('centers', 0.02214072729834908),
#    ('facilities', 0.019767883044293812),
#    ('environment', 0.017226759948461606),
#    ('access', 0.01570620198722774)]),
#  (10,
#   [('measures', 0.092380842032599053),
#    ('quality', 0.077820821260262546),
#    ('performance', 0.069476579222436344),
#    ('government', 0.049591497417367757),
#    ('life', 0.025916014373607278),
#    ('developed', 0.024796650118479639),
#    ('fair', 0.016476546976723017),
#    ('measurement', 0.014967900754065268),
#    ('definitions', 0.013866800035767382),
#    ('index', 0.013374835113969707)]),
#  (11,
#   [('energy', 0.12371084945388265),
#    ('environment', 0.090690020883510858),
#    ('electricity', 0.027522591132607205),
#    ('air', 0.02448100005593962),
#    ('sustainable', 0.024139471140549176),
#    ('action', 0.023631696929809619),
#    ('climate', 0.023112523604460807),
#    ('city', 0.019150364298185181),
#    ('clean', 0.01909891884790434),
#    ('facilities', 0.01847151888251522)]),
#  (12,
#   [('map', 0.07003231159311829),
#    ('"about"', 0.065737327359522146),
#    ('shows', 0.044643143524590485),
#    ('details', 0.037417466989238299),
#    ('tracking', 0.033865619389321588),
#    ('click', 0.028565691919877855),
#    ('view', 0.027447393223963716),
#    ('additional', 0.026872823680713778),
#    ('weekly', 0.021964112590207557),
#    ('information', 0.017908829658562275)]),
#  (13,
#   [('gas', 0.059972589629464695),
#    ('natural', 0.038247506812764911),
#    ('food', 0.035123659997646883),
#    ('greenhouse', 0.02737167049995624),
#    ('environment', 0.026272618464459947),
#    ('emissions', 0.023135082043847805),
#    ('costs', 0.021398374769158977),
#    ('resources', 0.020865670871248309),
#    ('program', 0.020842524225516069),
#    ('fuel', 0.016081016497170121)]),
#  (14,
#   [('health', 0.047486595563458037),
#    ('code', 0.041436774555512541),
#    ('statistics', 0.038542408744321223),
#    ('county', 0.035207719557086382),
#    ('codes', 0.029854335897479736),
#    ('zip', 0.029139372691221986),
#    ('public', 0.024872570253527144),
#    ('diego', 0.024784995832963057),
#    ('harbison', 0.023033852102136411),
#    ('crest', 0.021395606263276593)]),
#  (15,
#   [('budget', 0.14154768271395413),
#    ('finance', 0.061629847818770116),
#    ('fund', 0.052866707925857535),
#    ('year', 0.027361528382526451),
#    ('operating', 0.026714548673113327),
#    ('city', 0.026151540354093086),
#    ('fiscal', 0.023587756171379842),
#    ('funds', 0.020153544191078145),
#    ('calendar', 0.018291264587569866),
#    ('communities', 0.016813255820410825)]),
#  (16,
#   [('economy', 0.074831970475957757),
#    ('employment', 0.059024507694450813),
#    ('labor', 0.037518750233590671),
#    ('unemployment', 0.030420042880313702),
#    ('insurance', 0.022811919476438829),
#    ('credit', 0.02240291501623564),
#    ('workforce', 0.021053326053081162),
#    ('economic', 0.017523311551405966),
#    ('training', 0.016769979428771047),
#    ('federal', 0.015805104806649688)]),
#  (17,
#   [('services', 0.27536646810144061),
#    ('social', 0.095962651687079945),
#    ('human', 0.053809687721545367),
#    ('dfps', 0.052589282054521021),
#    ('information', 0.03466089006854034),
#    ('programs', 0.033066788534579276),
#    ('us', 0.030089170965030963),
#    ('definition', 0.022733622690420504),
#    ('visit', 0.02151984124994798),
#    ('state', 0.020155768734965274)]),
#  (18,
#   [('column', 0.063427308877555669),
#    ('update', 0.046675236579513182),
#    ('homeless', 0.041663950666934658),
#    ('annually', 0.030072376551628751),
#    ('frequency', 0.02926894249626533),
#    ('position', 0.021127522302048646),
#    ('city', 0.01984153972699073),
#    ('commercial', 0.01846514098874218),
#    ('daily', 0.016869053694575468),
#    ('salaries', 0.01558924337154113)]),
#  (19,
#   [('death', 0.048126995262336554),
#    ('maryland', 0.04203981078656735),
#    ('database', 0.028903753013522989),
#    ('deaths', 0.027176667718008366),
#    ('office', 0.027062908105413903),
#    ('department', 0.024200455450014258),
#    ('new', 0.020639763071301036),
#    ('cdc', 0.020246707002184408),
#    ('metadata', 0.018528581835236948),
#    ('citizens', 0.017503462164537666)]),
#  (20,
#   [('expected', 0.032218200719388315),
#    ('dept', 0.03192755749313185),
#    ('observed', 0.028518686601885064),
#    ('every', 0.023146698375314433),
#    ('300', 0.021255493076380451),
#    ('pacific', 0.021116246104674861),
#    ('physical', 0.020257410998302562),
#    ('performed', 0.018484869357599031),
#    ('contribution', 0.017489873926872384),
#    ('std', 0.01619190856680653)]),
#  (21,
#   [('public', 0.071331431077657451),
#    ('safety', 0.069027661647336119),
#    ('fire', 0.047750379014825345),
#    ('month', 0.020581987820630462),
#    ('calls', 0.017375649507546796),
#    ('police', 0.017078124466635133),
#    ('emergency', 0.016522104916252903),
#    ('response', 0.015789103751618325),
#    ('discharge', 0.015068830152377888),
#    ('incident', 0.014034152768794762)]),
#  (22,
#   [('arts', 0.030623882738573149),
#    ('grants', 0.027305070352776701),
#    ('live', 0.026616435603867498),
#    ('county', 0.02352575927246791),
#    ('includes', 0.019948024676078455),
#    ('library', 0.01873744681009169),
#    ('clearance', 0.01769201979004003),
#    ('grant', 0.01744185803724117),
#    ('inventory', 0.017416447546996693),
#    ('cps', 0.017216111917570089)]),
#  (23,
#   [('police', 0.049599652100346163),
#    ('user', 0.032265367100513642),
#    ('information', 0.029626460569977066),
#    ('page', 0.024435878993697473),
#    ('department', 0.023728883932669205),
#    ('use', 0.023314363268950755),
#    ('orleans', 0.01831277092169864),
#    ('injury', 0.017497753573167622),
#    ('may', 0.016658073483472296),
#    ('records', 0.01319973742765217)]),
#  (24,
#   [('official', 0.061094290910533561),
#    ('account', 0.04976604753946838),
#    ('accounts', 0.048301458649605035),
#    ('(openmichigan@michigan', 0.040820714695857956),
#    ('special', 0.029163998589317921),
#    ('nursing', 0.02877038841603027),
#    ('software', 0.026806546446223656),
#    ('gis', 0.023974220833955701),
#    ('use', 0.022528606483685758),
#    ('consumer', 0.022447395060642104)]),
#  (25,
#   [('tax', 0.11694941744290623),
#    ('revenue', 0.058281674929582826),
#    ('sales', 0.038634383980769106),
#    ('taxes', 0.034713010510365863),
#    ('local', 0.033205416149379233),
#    ('colorado', 0.030687046796886448),
#    ('government', 0.029706917267673681),
#    ('state', 0.021996118000518896),
#    ('department', 0.019154178963866255),
#    ('sale', 0.015211224135670038)]),
#  (26,
#   [('public', 0.16838176841104285),
#    ('safety', 0.1399822838525531),
#    ('crime', 0.063180867294822307),
#    ('police', 0.035971649940013783),
#    ('department', 0.01934244932463609),
#    ('illinois', 0.015211807554571162),
#    ('race', 0.013365201285222672),
#    ('reported', 0.011776909210955196),
#    ('crimes', 0.011550469075927439),
#    ('criminal', 0.010510578525453793)]),
#  (27,
#   [('water', 0.096124708891673349),
#    ('environment', 0.048101960808142975),
#    ('protection', 0.020628382724667733),
#    ('tx', 0.020203690273746876),
#    ('filed', 0.019569864371137932),
#    ('waste', 0.019271624659872911),
#    ('site', 0.019200525696858466),
#    ('quality', 0.018557602041230845),
#    ('environmental', 0.017395095439341653),
#    ('monitoring', 0.015888456167874085)]),
#  (28,
#   [('transportation', 0.049342201509275964),
#    ('plans', 0.0463408207807137),
#    ('iowa', 0.03724002146171048),
#    ('area', 0.031583902009011684),
#    ('transit', 0.029746652763280607),
#    ('operations', 0.029650998680989683),
#    ('region', 0.028630893370822634),
#    ('bus', 0.023940404924489834),
#    ('priority', 0.019765257375106392),
#    ('people', 0.0157596265394866)]),
#  (29,
#   [('planning', 0.060932885606218332),
#    ('county', 0.059246046260552521),
#    ('district', 0.059082234604936598),
#    ('districts', 0.046091488648481185),
#    ('boundaries', 0.037211490590221732),
#    ('city', 0.029524721059023727),
#    ('areas', 0.027095006552687029),
#    ('zoning', 0.026634642336752109),
#    ('gis', 0.024439676328900622),
#    ('council', 0.023082692493783637)]),
#  (30,
#   [('mateo', 0.04184248749834401),
#    ('city', 0.023985079812541651),
#    ('gis', 0.019805378260364801),
#    ('land', 0.019219281849626336),
#    ('county', 0.018870460262658366),
#    ('parcel', 0.017318355184099247),
#    ('map', 0.017293542672449272),
#    ('point', 0.017217088467835123),
#    ('survey', 0.016483910162221081),
#    ('feature', 0.016048488156929334)]),
#  (31,
#   [('politics', 0.11069826014751941),
#    ('government', 0.098315050573643273),
#    ('election', 0.038259777750699074),
#    ('campaign', 0.030948562034191236),
#    ('elections', 0.029682305103395073),
#    ('commission', 0.029314992871497855),
#    ('results', 0.024928316671568231),
#    ('city', 0.02132785699829063),
#    ('460', 0.020080548927070931),
#    ('finance', 0.019735216016406935)]),
#  (32,
#   [('open', 0.11136160624479899),
#    ('created', 0.066633337086342601),
#    ('items', 0.046975156803616497),
#    ('clear', 0.024971656082104495),
#    ('volume', 0.017569028429596321),
#    ('please', 0.01620818951157825),
#    ('presented', 0.015509271243001166),
#    ('difficult', 0.014152486549053123),
#    ('potential', 0.013902418105983163),
#    ('note', 0.012958764775942001)]),
#  (33,
#   [('finance', 0.071043372892685447),
#    ('summary', 0.060625406434642808),
#    ('dashboard', 0.057306369737017436),
#    ('ethics', 0.046020336169751791),
#    ('form', 0.040459920451206687),
#    ('management', 0.032747889878733547),
#    ('board', 0.023358112210499077),
#    ('pension', 0.017133753473461615),
#    ('includes', 0.016256755260059545),
#    ('last', 0.016102898579562843)]),
#  (34,
#   [('education', 0.18150475758690063),
#    ('school', 0.081857692569206983),
#    ('schools', 0.0317766682175891),
#    ('students', 0.029571629399532486),
#    ('public', 0.017173423581827232),
#    ('governance', 0.016783317325556272),
#    ('state', 0.016578579370884614),
#    ('year', 0.016159604793580536),
#    ('student', 0.016139734254594727),
#    ('district', 0.01600362788318669)]),
#  (35,
#   [('infrastructure', 0.082445242432479721),
#    ('city', 0.065893376157151143),
#    ('public', 0.032845769972150357),
#    ('maps', 0.030519532936435358),
#    ('works', 0.027935011789728573),
#    ('dallas', 0.022443140628194077),
#    ('los', 0.019882704408148669),
#    ('angeles', 0.019192175434757104),
#    ('types', 0.015113120712693303),
#    ('way', 0.013887150827763371)]),
#  (36,
#   [('census', 0.078804980837745758),
#    ('indicators', 0.077373830079416436),
#    ('survey', 0.048035159786913896),
#    ('includes', 0.044835173852544735),
#    ('indicator', 0.036924523941196177),
#    ('community', 0.033221116599808108),
#    ('demographics', 0.028209305968815383),
#    ('bureau', 0.023872041750842676),
#    ('u', 0.021139289477577056),
#    ('level', 0.019204313061601801)]),
#  (37,
#   [('financial', 0.095961100691599369),
#    ('permits', 0.066863273960211606),
#    ('building', 0.063195390054562622),
#    ('permit', 0.054456521696982667),
#    ('expenditures', 0.042924738948058642),
#    ('guide', 0.025058053425860767),
#    ('issued', 0.023243432964197546),
#    ('construction', 0.022884617487689943),
#    ('information', 0.02279686241791478),
#    ('filter', 0.021954851645997791)]),
#  (38,
#   [('plan', 0.043864302305066827),
#    ('strategic', 0.034170749236072259),
#    ('master', 0.02434141736730544),
#    ('community', 0.020477914960891377),
#    ('fewer', 0.019330699927391008),
#    ('limitations', 0.018044419984850159),
#    ('registry', 0.017693548198715405),
#    ('cause', 0.016906069114867663),
#    ('years', 0.015944418985748578),
#    ('information', 0.014420142106983924)]),
#  (39,
#   [('health', 0.30531189584891172),
#    ('san', 0.061101772036273934),
#    ('county', 0.058639270651817503),
#    ('care', 0.028005505975059769),
#    ('counties', 0.019925395256915498),
#    ('system', 0.016377029581779941),
#    ('facilities', 0.014007603368699854),
#    ('network', 0.013561457306569633),
#    ('home', 0.011206164684491395),
#    ('francisco', 0.010310472003196668)]),
#  (40,
#   [('finance', 0.16474209816597238),
#    ('year', 0.062366577351005315),
#    ('state', 0.053382253954750457),
#    ('monthly', 0.050696248199469038),
#    ('fiscal', 0.047622222135699312),
#    ('payments', 0.035719919718136567),
#    ('government', 0.02645402325871795),
#    ('june', 0.022577028747073),
#    ('july', 0.021675911556054386),
#    ('report', 0.021590010484289327)]),
#  (41,
#   [('service', 0.087262714441883243),
#    ('requests', 0.035031694542933929),
#    ('inspection', 0.032678935192867728),
#    ('inspections', 0.031350351826353977),
#    ('311', 0.026311943104393398),
#    ('public', 0.025968462717016926),
#    ('violations', 0.023768792319548215),
#    ('request', 0.022587674832020798),
#    ('complaints', 0.019370415310915674),
#    ('days', 0.018002600321326952)]),
#  (42,
#   [('information', 0.024602766215276441),
#    ('list', 0.021580669434979348),
#    ('code', 0.017461004706817183),
#    ('required', 0.016538859124753839),
#    ('political', 0.013997537552533643),
#    ('utah', 0.013858241707600623),
#    ('public', 0.013319630833329574),
#    ('city', 0.013266613262239497),
#    ('years', 0.012297917571542876),
#    ('see', 0.012277655731227213)]),
#  (43,
#   [('state', 0.1756382967463313),
#    ('new', 0.13340351799805059),
#    ('michigan', 0.10266572561037926),
#    ('york', 0.077727077387110127),
#    ('information', 0.029283874552224455),
#    ('check', 0.02032209041652535),
#    ('measurements', 0.019708043153636445),
#    ('jobs', 0.017040272127524295),
#    ('licensing', 0.016976894067415114),
#    ('ny', 0.016777641736857838)]),
#  (44,
#   [('book', 0.040135367577023996),
#    ('lead', 0.040111314911710098),
#    ('stations', 0.035230307653653078),
#    ('databook', 0.03363611816437783),
#    ('station', 0.032779991270326547),
#    ('closed', 0.023280298248918037),
#    ('ecology', 0.022906441104600394),
#    ('solar', 0.019267555473289202),
#    ('power', 0.01904494570812373),
#    ('residential', 0.016817032555105343)]),
#  (45,
#   [('report', 0.11604973949315449),
#    ('performance', 0.072106784996400927),
#    ('city', 0.064553993348579072),
#    ('goal', 0.049701354025019934),
#    ('resultsnola', 0.045459898953553526),
#    ('administration', 0.044925526194230785),
#    ("city's", 0.03417954310339625),
#    ('management', 0.033852728584638718),
#    ('key', 0.033837307690521595),
#    ('topeka', 0.022145009545635606)]),
#  (46,
#   [('address', 0.042514297658594498),
#    ('name', 0.028895265435991142),
#    ('number', 0.026095926621437948),
#    ('facility', 0.021195054756114773),
#    ('patient', 0.018728329073792953),
#    ('location', 0.017356509556266626),
#    ('contains', 0.014702734565212696),
#    ('type', 0.014078242116513321),
#    ('g', 0.013900974382997767),
#    ('transfer', 0.013899331867379633)]),
#  (47,
#   [('care', 0.11036088229652928),
#    ('finance', 0.049033830573026793),
#    ('provider', 0.044146456939484949),
#    ('child', 0.041722110536953544),
#    ('cost', 0.034993745722234584),
#    ('plan', 0.030778145306684032),
#    ('day', 0.028558344716958277),
#    ('bay', 0.025286386344854205),
#    ('government', 0.024128574624377789),
#    ('fee', 0.018205044303512732)]),
#  (48,
#   [('business', 0.080327130459714152),
#    ('license', 0.032302648156979613),
#    ('job', 0.022002624988460773),
#    ('contracts', 0.021934165455248577),
#    ('businesses', 0.019770850331225706),
#    ('vendor', 0.017832975411663454),
#    ('owned', 0.017528163358468088),
#    ('contract', 0.017516996738737415),
#    ('licenses', 0.016969889175799842),
#    ('certified', 0.016688461456116979)]),
#  (49,
#   [('development', 0.17602775675090593),
#    ('housing', 0.15221265764931263),
#    ('economic', 0.058854109443175158),
#    ('community', 0.04859194305354804),
#    ('infrastructure', 0.019040125293198554),
#    ('managed', 0.018304696035360443),
#    ('medicaid', 0.017876406351462711),
#    ('department', 0.014023829088608938),
#    ('buildings', 0.013775405992175799),
#    ('economy', 0.012347394313369113)]),
#  (50,
#   [('program', 0.03251146357097217),
#    ('employees', 0.028975172275721717),
#    ('adult', 0.024408505499127525),
#    ('employee', 0.02429680205275107),
#    ('annual', 0.020498612612776752),
#    ('names', 0.018217941353291824),
#    ('full', 0.017909118396460151),
#    ('abuse', 0.016209683412924534),
#    ('nutrition', 0.015767712459609552),
#    ('beginning', 0.014213770821721556)]),
#  (51,
#   [('cook', 0.05830855785510166),
#    ('high', 0.057680528554684904),
#    ('cases', 0.039417055039367849),
#    ('youth', 0.03165394178442571),
#    ('case', 0.027938083160155187),
#    ('court', 0.02661638705111698),
#    ('enrollment', 0.018080429121202373),
#    ('college', 0.01773522389517114),
#    ('wa', 0.016770584173977882),
#    ('gis/maps', 0.016618223819135965)])]

# %% [markdown]
# ## Analysis of LDA Model Topic Formation:

# %% [markdown]
# This is a very decent topic analysis. By my count, **we've created 48 genuinely useful "clusters" of latent topics.** Since topic analysis is probabilistic, and our data contains "noise" (that is, words either far too specific or far too common to add real meaning) to begin with, **we have a few topics that won't help us.**
# - Topic 32 is just too vague. It probably has something to do with some open government performance metrics, but there are no words to really a distinguish it.  This is not a failure of the algorithm; I don't doubt these words really are occuring together alot in the data. But "open, created, items" doesn't tell us much.
# - Topic 24 clearly has to do with some "special" software/gis for open data (probably having to do with nursing) -- it looks like through the openmichigan portal. Again, these words are quite likely appearing together. But the practical application of a topic like this when it comes to determinging what is popular in the real world is limited.
# - Topic 42 has a similar problem to topics 32 and 42 topics, but is a little more clear for content type. It looks like political information for several years. But we can't really tell more specifics.
# - Topic 43 is what I'd call a "parochial" topic; it's clearly about common information like jobs and licensing from new york and michigan. Again, not useful as its own topic - but my spin is that this helps isolate "new york" and "ny" to keep them from inflating other topic views.
#
# **Other topics are useful, but may mix content. It could be a vagary of the English language, or it might actually reveal new insights:**
# - Topic 51 is a topic that tells us something, but it appears to be a mix of youth court cases and youth college enrollment. This could be that "enrollment" is used in English in the context of college and court-mandated programs. Then again, this could be "at-risk youth outcome statistics - either court or college (or both).
# - Topic 37 appears to be about the construction, permits, and financials of building projects; since these are are pretty closely related in real life, however, I'd argue this is a good topic formation.
#
# **Many topics contain a proper name, but clearly identify something useful:**
# - Topic 9 -- "recreation", "parks", "jersey", "park", "centers", "neighborhood", "centers", etc. is clearly about parks and recreation facilities. It just contains jersey. Because of how we'll award our views/downloads counts to each topic, "jersey" should only skew this slightly. Again, this is just "error" (but not really error, according to the model - jersey probably had a lot of parks and recreation datasets) we have to tolerate if we can't exclude proper names as stop words.
#
# **Topic 13 has a seemingly weird outlier:**
# - Topic 13 is clearly about gas & fuel emissions, but also contains "food". I'm guessing "food" is linked to "gas" by the word "natural" across many datasets (natural food, natural gas). This is just noise we will have to tolerate.
#
# **Many topics are absolutely beautiful. A few examples:**
# - Topic 11 -- energy, environment, electricity, air, sustainable, action, climate, city, clean, facilities -- identifies a city's environmental initiatives with words I wouldn't have even thought of to group together.
# - Topic 31 -- politics, government, election, campaign, elections, commissions, results, etc -- leaves no doubt about its content.
# - Topic 5 -- locations, bacteria, hours, culture, county, levels, contact, directory, e [as in e coli], contains -- is amazing. Words that could be all sorts of different topics that become so clear in context together. This is about local bacteria levels! (Presumably in lakes)

# %% [markdown]
# ## Load Saved Corpus:
# - We are going to use our LDA model to transform this corpus so we can return the *topic composition* of each *document*.

# %%
corpus = corpora.MmCorpus('8.14corpus.mm')

# %%
corpus_lda = lda_52_sixty[corpus] #just a wrapper -- will convert on the fly when you call it

# %% [markdown]
# **Let's check that this lines up:**

# %%
for doc in corpus_lda[20000:20003]:
    print(doc)
# Out:
# [(31, 0.50961538461538491)]
# [(31, 0.50961538461538491)]
# [(31, 0.50961538461538214)]

# %%
big_mash.big_mash[20000:20003]
# Out:
# 20000    ['politics']
# 20001    ['politics']
# 20002    ['politics']
# Name: big_mash, dtype: object

# %%
lda_52_sixty.show_topic(31)
# Out:
# [('politics', 0.11069826014751941),
#  ('government', 0.098315050573643273),
#  ('election', 0.038259777750699074),
#  ('campaign', 0.030948562034191236),
#  ('elections', 0.029682305103395073),
#  ('commission', 0.029314992871497855),
#  ('results', 0.024928316671568231),
#  ('city', 0.02132785699829063),
#  ('460', 0.020080548927070931),
#  ('finance', 0.019735216016406935)]

# %% [markdown]
# All three documents have only the tag 'politics" to idenfity them. As we can see, our corpus transformation identifies document 31 as composing .5 of all of them. Document 31 is a politics and elections topic. Looks good.

# %%
len(corpus_lda)
# Out:
# 21807

# %%
corpus_lda_list = list(corpus_lda[0:21790])

# %% [markdown]
# For some reason we can't convert our entire corpus into a list. It is truly mind boggling, and the potential issue is beyond my level of knowledge. But since we can convert most of the corpus, we'll make a (slightly abridged) new dataframe and add our topic compositions:

# %%
stats = big_mash.copy()
stats = stats.iloc[0:21790, :]
stats = stats.assign(topic_comp = corpus_lda_list)
stats.iloc[9009:9012, :] #random slice
# Out:
#       Unnamed: 0                                               name  \
# 9009        9009  Returning Citizen Child Support & Inmate Oblig...
# 9010        9010  Breakfast, Lunch, and At-Risk Afterschool Meal...
# 9011        9011  Total Light Rail Trips Taken by Year: Column C...
#
#                                             description  \
# 9009  ['Data', 'are', 'provided', 'by', 'the', 'Depa...
# 9010  ['This', 'dataset', 'tracks', 'participation',...
# 9011  ['Data', 'are', 'provided', 'by', 'the', 'Mary...
#
#                                         attribution  \
# 9009            Department of Human Resources (DHR)
# 9010  Maryland State Department of Education (MSDE)
# 9011                     Maryland Transit Authority
#
#                                      columns_field_name  \
# 9009  ['number_of_released_inmates_who_pay_any_perce...
# 9010  ['at_risk_afterschool_meals_program_average_da...
# 9011                      ['fiscal_year', 'light_rail']
#
#                                            columns_name     type  \
# 9009  ['Number of released inmates who pay any perce...  dataset
# 9010  ['At-Risk Afterschool Program Avg. Daily Parti...    chart
# 9011                      ['Fiscal Year', 'Light Rail']    chart
#
#               categories            domain_category  \
# 9009                  []  Health and Human Services
# 9010       ['education']  Health and Human Services
# 9011  ['transportation']             Transportation
#
#                                             domain_tags provenance  \
# 9009  ['inmate obligors', 'prisoner re-entry', 're-e...   official
# 9010  ['meal', 'education', 'lunch', 'breakfast', 'c...   official
# 9011  ['ridership', 'paratransit', 'mobility', 'rail...   official
#
#       download_count  page_views_last_month  page_views_last_week  \
# 9009        1433.000                 20.000                 1.000
# 9010         115.000                 26.000                 2.000
# 9011         181.000                 12.000                 1.000
#
#       page_views_total  page_views_total_log             domain  \
# 9009           628.000                 9.297  data.maryland.gov
# 9010           627.000                 9.295  data.maryland.gov
# 9011           621.000                 9.281  data.maryland.gov
#
#                                                    mash  \
# 9009  ['inmate', 'obligors', 'prisoner', 're-entry',...
# 9010  ['meal', 'education', 'lunch', 'breakfast', 'c...
# 9011  ['ridership', 'paratransit', 'mobility', 'rail...
#
#                                                big_mash  \
# 9009  ['inmate', 'obligors', 'prisoner', 're-entry',...
# 9010  ['meal', 'education', 'lunch', 'breakfast', 'c...
# 9011  ['ridership', 'paratransit', 'mobility', 'rail...
#
#                                              topic_comp
# 9009  [(4, 0.210601353097), (6, 0.0182243633613), (1...
# 9010  [(1, 0.0776627218935), (2, 0.039201183432), (7...
# 9011  [(0, 0.0156918612058), (2, 0.0263660953474), (...

# %% [markdown]
# ### Let's poke around to see how our model's calculated topic compositions do:

# %%
big_mash.big_mash[900]
# Out:
# "['police', 'traffic', 'fatality', 'fatalities', 'public', 'safety', 'Dataset', 'of', 'traffic', 'fatalities', 'January', '1st', 'December', '31st', '2015', 'The', 'Austin', 'Police', 'Department', 'Fatality', 'database', 'contains', 'only', 'those', 'crashes', 'investigated', 'by', 'APD', 'and', 'is', 'continuously', 'being', 'updated', 'due', 'to', 'on', 'going', 'investigations', 'The', 'data', 'provided', 'here', 'represents', 'a', 'snapshot', 'of', 'Traffic', 'Fatality', 'information', 'at', 'a', 'specific', 'point', 'in', 'time', 'and', 'may', 'change', 'Due', 'to', 'the', 'long', 'processing', 'times', 'for', 'toxicology', 'testing', 'impairment', 'and', 'suspected', 'impairment', 'statistics', 'are', 'based', 'on', 'the', 'initial', 'assessment', 'of', 'the', 'Detectives', 'and', 'Medical', 'Examiner']"

# %% [markdown]
# This dataset is about traffic fatalities and crashes as recorded by the police department.

# %%
for index, score in sorted(lda_52_sixty[corpus[900]], key=lambda tup: -1*tup[1]): 
    print("Score: {}\t Topic: {} \n".format(score, lda_52_sixty.print_topic(index, 15))) #15 word topics
# Out:
# Score: 0.5480149120022656	 Topic: 0.071*"public" + 0.069*"safety" + 0.048*"fire" + 0.021*"month" + 0.017*"calls" + 0.017*"police" + 0.017*"emergency" + 0.016*"response" + 0.015*"discharge" + 0.014*"incident" + 0.014*"department" + 0.011*"incidents" + 0.011*"time" + 0.011*"discharges" + 0.011*"medical"
#
# Score: 0.3004543236048098	 Topic: 0.046*"information" + 0.025*"tab" + 0.024*"projects" + 0.018*"concerning" + 0.018*"may" + 0.017*"contains" + 0.016*"project" + 0.014*"provided" + 0.014*"additional" + 0.012*"improvement" + 0.010*"capital" + 0.009*"totals" + 0.009*"available" + 0.009*"release" + 0.008*"due"
#
# Score: 0.051468371213253206	 Topic: 0.096*"water" + 0.048*"environment" + 0.021*"protection" + 0.020*"tx" + 0.020*"filed" + 0.019*"waste" + 0.019*"site" + 0.019*"quality" + 0.017*"environmental" + 0.016*"monitoring" + 0.015*"activity" + 0.013*"facility" + 0.012*"recycling" + 0.012*"activities" + 0.011*"modified"
#
# Score: 0.025782322551716974	 Topic: 0.168*"public" + 0.140*"safety" + 0.063*"crime" + 0.036*"police" + 0.019*"department" + 0.015*"illinois" + 0.013*"race" + 0.012*"reported" + 0.012*"crimes" + 0.011*"criminal" + 0.010*"statistics" + 0.010*"statistical" + 0.010*"part" + 0.009*"arrests" + 0.009*"enforcement"
#
# Score: 0.019940912786328306	 Topic: 0.070*"locations" + 0.026*"bacteria" + 0.026*"hours" + 0.025*"culture" + 0.024*"county" + 0.022*"levels" + 0.021*"contact" + 0.020*"directory" + 0.019*"e" + 0.019*"contains" + 0.016*"including" + 0.014*"found" + 0.014*"information" + 0.014*"area" + 0.013*"posted"
#
# Score: 0.01929159654447894	 Topic: 0.092*"measures" + 0.078*"quality" + 0.069*"performance" + 0.050*"government" + 0.026*"life" + 0.025*"developed" + 0.016*"fair" + 0.015*"measurement" + 0.014*"definitions" + 0.013*"index" + 0.012*"key" + 0.011*"hospitalizations" + 0.011*"current" + 0.011*"livable" + 0.010*"countystat_measures"
#
# Score: 0.01902192027150731	 Topic: 0.060*"gas" + 0.038*"natural" + 0.035*"food" + 0.027*"greenhouse" + 0.026*"environment" + 0.023*"emissions" + 0.021*"costs" + 0.021*"resources" + 0.021*"program" + 0.016*"fuel" + 0.014*"agriculture" + 0.013*"information" + 0.013*"affordable" + 0.013*"plus" + 0.013*"total"

# %% [markdown]
# And indeed, our highest topic affinity comes from a public safety calls/emergency response and medical topic. That's a good match.
#
# However, we can see some potential pitfalls here. Several other topics register, including "government performance measurements" tag. This speaks to the need to set a threshold for awarding a topic "credit" -- i.e. it composes more than .2 of a topic, or it's the largest topic.

# %%
big_mash.big_mash[20789]
# Out:
# "['benefits', 'veterans', 'services', 'veterans', 'measure', 'a', 'infrastructure', 'health', '&', 'human', 'services', 'Quarterly', 'Measure', 'A', 'dashboard', 'data', 'for', 'Veterans', 'Services', 'Assessment', 'and', 'Staffing', 'initiative', 'Claims', 'data', 'sourced', 'from', 'VetPro', 'DVS', '19', 'reports;', 'Office', 'contacts', 'sources', 'from', 'Daily', 'Appointment', 'Logs']"

# %%
for index, score in sorted(lda_52_sixty[corpus[20789]], key=lambda tup: -1*tup[1]): 
    print("Score: {}\t Topic: {} \n".format(score, lda_52_sixty.print_topic(index, 15)))
# Out:
# Score: 0.19399944234439653	 Topic: 0.080*"business" + 0.032*"license" + 0.022*"job" + 0.022*"contracts" + 0.020*"businesses" + 0.018*"vendor" + 0.018*"owned" + 0.018*"contract" + 0.017*"licenses" + 0.017*"certified" + 0.016*"economy" + 0.016*"city" + 0.016*"list" + 0.015*"quantities" + 0.015*"vendors"
#
# Score: 0.13777744063768205	 Topic: 0.049*"transportation" + 0.046*"plans" + 0.037*"iowa" + 0.032*"area" + 0.030*"transit" + 0.030*"operations" + 0.029*"region" + 0.024*"bus" + 0.020*"priority" + 0.016*"people" + 0.014*"plan" + 0.013*"areas" + 0.013*"(including" + 0.012*"two" + 0.012*"dot"
#
# Score: 0.13194214859348494	 Topic: 0.176*"development" + 0.152*"housing" + 0.059*"economic" + 0.049*"community" + 0.019*"infrastructure" + 0.018*"managed" + 0.018*"medicaid" + 0.014*"department" + 0.014*"buildings" + 0.012*"economy" + 0.012*"assistance" + 0.011*"program" + 0.010*"family" + 0.008*"benefits" + 0.008*"addressing"
#
# Score: 0.10411140583554371	 Topic: 0.305*"health" + 0.061*"san" + 0.059*"county" + 0.028*"care" + 0.020*"counties" + 0.016*"system" + 0.014*"facilities" + 0.014*"network" + 0.011*"home" + 0.010*"francisco" + 0.010*"information" + 0.009*"providers" + 0.009*"immunization" + 0.008*"alone" + 0.008*"public"
#
# Score: 0.06962864721485408	 Topic: 0.058*"cook" + 0.058*"high" + 0.039*"cases" + 0.032*"youth" + 0.028*"case" + 0.027*"court" + 0.018*"enrollment" + 0.018*"college" + 0.017*"wa" + 0.017*"gis/maps" + 0.014*"non" + 0.014*"graduation" + 0.011*"less" + 0.011*"year" + 0.011*"four"
#
# Score: 0.042889359016288285	 Topic: 0.025*"information" + 0.022*"list" + 0.017*"code" + 0.017*"required" + 0.014*"political" + 0.014*"utah" + 0.013*"public" + 0.013*"city" + 0.012*"years" + 0.012*"see" + 0.012*"office" + 0.012*"field" + 0.011*"section" + 0.011*"file" + 0.011*"must"
#
# Score: 0.04096265752525667	 Topic: 0.117*"tax" + 0.058*"revenue" + 0.039*"sales" + 0.035*"taxes" + 0.033*"local" + 0.031*"colorado" + 0.030*"government" + 0.022*"state" + 0.019*"department" + 0.015*"sale" + 0.015*"information" + 0.013*"runs" + 0.013*"credits" + 0.013*"cities" + 0.012*"unincorporated"
#
# Score: 0.037909374257837074	 Topic: 0.033*"program" + 0.029*"employees" + 0.024*"adult" + 0.024*"employee" + 0.020*"annual" + 0.018*"names" + 0.018*"full" + 0.016*"abuse" + 0.016*"nutrition" + 0.014*"beginning" + 0.014*"table" + 0.013*"practices" + 0.012*"administration" + 0.011*"number" + 0.011*"received"
#
# Score: 0.0374932028853666	 Topic: 0.110*"care" + 0.049*"finance" + 0.044*"provider" + 0.042*"child" + 0.035*"cost" + 0.031*"plan" + 0.029*"day" + 0.025*"bay" + 0.024*"government" + 0.018*"fee" + 0.018*"franklin" + 0.018*"act" + 0.017*"effective" + 0.013*"administrative" + 0.012*"efficient"
#
# Score: 0.036687104502038055	 Topic: 0.131*"property" + 0.052*"consumption" + 0.046*"real" + 0.031*"value" + 0.025*"properties" + 0.022*"significant" + 0.022*"easy" + 0.020*"usage" + 0.020*"assessment" + 0.015*"company" + 0.015*"percentages" + 0.015*"city" + 0.014*"estate" + 0.014*"values" + 0.012*"government"
#
# Score: 0.03596261241271573	 Topic: 0.079*"census" + 0.077*"indicators" + 0.048*"survey" + 0.045*"includes" + 0.037*"indicator" + 0.033*"community" + 0.028*"demographics" + 0.024*"bureau" + 0.021*"u" + 0.019*"level" + 0.018*"estimates" + 0.017*"retirement" + 0.013*"count" + 0.013*"us" + 0.012*"poverty"
#
# Score: 0.03514588859416444	 Topic: 0.132*"population" + 0.092*"county" + 0.084*"demographics" + 0.043*"age" + 0.028*"total" + 0.019*"king" + 0.019*"washington" + 0.018*"montgomery" + 0.018*"number" + 0.017*"years" + 0.015*"ratio" + 0.014*"center" + 0.014*"gender" + 0.012*"governor's" + 0.011*"department"
#
# Score: 0.03514588859416444	 Topic: 0.075*"economy" + 0.059*"employment" + 0.038*"labor" + 0.030*"unemployment" + 0.023*"insurance" + 0.022*"credit" + 0.021*"workforce" + 0.018*"economic" + 0.017*"training" + 0.016*"federal" + 0.015*"industry" + 0.014*"prosperous" + 0.014*"wages" + 0.013*"work" + 0.012*"compensation"
#
# Score: 0.03514588859416444	 Topic: 0.071*"finance" + 0.061*"summary" + 0.057*"dashboard" + 0.046*"ethics" + 0.040*"form" + 0.033*"management" + 0.023*"board" + 0.017*"pension" + 0.016*"includes" + 0.016*"last" + 0.016*"city" + 0.014*"see" + 0.012*"system" + 0.012*"period" + 0.012*"reduction"

# %% [markdown]
# Here's a great example of **INHERENT** uncertainty in our model. A human eye can barely tell what the metadata on this dataset is saying -- it looks like veterans services, specifically health care -- as indicated by "Daily Appointment Logs". It also contains a random infrastructure tag and just several words that don't add much real life meaning.
#
# Our model tries to match it with a business licenses topic. I wouldn't say that's right - but look at the composition score. It's not even .2. **This speaks to the need to set a "cut off" to get credit for a topic's views. **

# %%
big_mash.big_mash[6718]
# Out:
# "['finance', 'health', 'Insurance', 'plan', 'premiums', 'available', 'to', 'Iowa', 'individuals', 'for', '2017', 'under', 'the', 'Affordable', 'Care', 'Act']"

# %%
for index, score in sorted(lda_52_sixty[corpus[6718]], key=lambda tup: -1*tup[1]): 
    print("Score: {}\t Topic: {} \n".format(score, lda_52_sixty.print_topic(index, 15)))
# Out:
# Score: 0.3175787077909651	 Topic: 0.110*"care" + 0.049*"finance" + 0.044*"provider" + 0.042*"child" + 0.035*"cost" + 0.031*"plan" + 0.029*"day" + 0.025*"bay" + 0.024*"government" + 0.018*"fee" + 0.018*"franklin" + 0.018*"act" + 0.017*"effective" + 0.013*"administrative" + 0.012*"efficient"
#
# Score: 0.2573984964913682	 Topic: 0.075*"economy" + 0.059*"employment" + 0.038*"labor" + 0.030*"unemployment" + 0.023*"insurance" + 0.022*"credit" + 0.021*"workforce" + 0.018*"economic" + 0.017*"training" + 0.016*"federal" + 0.015*"industry" + 0.014*"prosperous" + 0.014*"wages" + 0.013*"work" + 0.012*"compensation"
#
# Score: 0.09159134428015532	 Topic: 0.049*"transportation" + 0.046*"plans" + 0.037*"iowa" + 0.032*"area" + 0.030*"transit" + 0.030*"operations" + 0.029*"region" + 0.024*"bus" + 0.020*"priority" + 0.016*"people" + 0.014*"plan" + 0.013*"areas" + 0.013*"(including" + 0.012*"two" + 0.012*"dot"
#
# Score: 0.08984170784776785	 Topic: 0.176*"development" + 0.152*"housing" + 0.059*"economic" + 0.049*"community" + 0.019*"infrastructure" + 0.018*"managed" + 0.018*"medicaid" + 0.014*"department" + 0.014*"buildings" + 0.012*"economy" + 0.012*"assistance" + 0.011*"program" + 0.010*"family" + 0.008*"benefits" + 0.008*"addressing"
#
# Score: 0.08493589743589744	 Topic: 0.132*"population" + 0.092*"county" + 0.084*"demographics" + 0.043*"age" + 0.028*"total" + 0.019*"king" + 0.019*"washington" + 0.018*"montgomery" + 0.018*"number" + 0.017*"years" + 0.015*"ratio" + 0.014*"center" + 0.014*"gender" + 0.012*"governor's" + 0.011*"department"
#
# Score: 0.08493589743589744	 Topic: 0.060*"gas" + 0.038*"natural" + 0.035*"food" + 0.027*"greenhouse" + 0.026*"environment" + 0.023*"emissions" + 0.021*"costs" + 0.021*"resources" + 0.021*"program" + 0.016*"fuel" + 0.014*"agriculture" + 0.013*"information" + 0.013*"affordable" + 0.013*"plus" + 0.013*"total"

# %% [markdown]
# We haven't really created a "health insurance" topic tag. However, the top topic for this metadata is topic that tries to match provider information and finances - it's top words "care, finance, provider" -- actually match a real life dataset about ACA insurance plans pretty well! **This is a good example of the model not being perfect, but still adding value.**
#
# **Also note** our second highest affinity comes from an economy and unemployment topic, which includes "insurance". However, I bet this is in the context of unemployment insurance!

# %%
big_mash.big_mash[18]
# Out:
# "['housing', 'Office', 'of', 'Housing', 'Data']"

# %%
for index, score in sorted(lda_52_sixty[corpus[18]], key=lambda tup: -1*tup[1]): 
    print("Score: {}\t Topic: {} \n".format(score, lda_52_sixty.print_topic(index, 15)))
# Out:
# Score: 0.5048076923076926	 Topic: 0.176*"development" + 0.152*"housing" + 0.059*"economic" + 0.049*"community" + 0.019*"infrastructure" + 0.018*"managed" + 0.018*"medicaid" + 0.014*"department" + 0.014*"buildings" + 0.012*"economy" + 0.012*"assistance" + 0.011*"program" + 0.010*"family" + 0.008*"benefits" + 0.008*"addressing"
#
# Score: 0.25480769230769246	 Topic: 0.048*"death" + 0.042*"maryland" + 0.029*"database" + 0.027*"deaths" + 0.027*"office" + 0.024*"department" + 0.021*"new" + 0.020*"cdc" + 0.019*"metadata" + 0.018*"citizens" + 0.017*"among" + 0.017*"vital" + 0.015*"state" + 0.014*"infants" + 0.014*"national"

# %% [markdown]
# Solid match to a housing and community assistance topic.

# %% [markdown]
# # Now let's calculate the popularity of each topic across all datasets
# - We will need some way to give a topic "credit" for the views and downloads of a dataset that it matches.

# %% [markdown]
# ## "Winner take all" popularity metric:**
# - **Scoring Rules:**
#     - Only the topic that composes the largest share of a document scores "points" for its "Adjusted Popularity" total.
#     - If a topic composes the largest share of that document, its "points" are its composition score times that dataset's combined log views and downloads.
#         - We're using log views so as not to overweigh datasets that just have alot of eyeballs on them (like ones from NYC).
#     - So, in our example above, the "development, housing, economic, etc..." dataset would score .504 times that dataset's (log views + downloads)
#     - Remember, each "document" is just a list of words from one of 28000 datasets' metadata.

# %% [markdown]
# First **let's remove healthcare.gov data from our dataset**; it inadvertently crept in there.

# %%
topics = stats[stats.domain != 'data.healthcare.gov']

# %%
def winner_take_all_pop(df):
    results_dict = {}
    df = df.fillna(0) #have to fill NaNs or you'll get wonky results

    for row_num in df.index:
        tup_list = df.topic_comp[row_num] #list of (topic, doc composition) tuples
        
        #neat little trick to return only the tuple w/highest index[1] value
        winner_tuple = max(tup_list, key=lambda item:item[1])  
            
        if not winner_tuple[0] in results_dict: #if not in dict, add it with its score
            #must use .loc, treating row_num like a label and not an integer
            results_dict[winner_tuple[0]] = (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
        else:
            pass
        
        if winner_tuple[0] in results_dict: #if in dict, increment that key's value with score
            results_dict[winner_tuple[0]] += (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
    
    return results_dict

# %%
winners_dict = winner_take_all_pop(topics)
#winners_dict #can uncomment just to double check dict numbers align with df topic number

# %% [markdown]
# Now let's make a quick and dirty function to replace these topic numbers with names in a sorted df for easy analysis:

# %%
def dict_to_df(d):
    df = pd.DataFrame.from_dict(d, orient='index')
    df = df.rename(index=str, columns={0:"Adjusted_Popularity"})
    df = df.reset_index() #DON'T drop; our index carries real value as it is our topic numbers
    df = df.rename(columns={'index': 'Topic Number'}) #when you reset_index with drop=False, you get orig index as col
    df['Topic Number'] = pd.to_numeric(df['Topic Number'])

    df = df.sort_values(by='Topic Number', ascending=True) 

    words_in_topics = [tup[1] for tup in lda_52_sixty.show_topics(num_topics=52, formatted=False)]
    df['Topic'] = words_in_topics

    df[["topic1", "topic2", "topic3", "topic4", 
           "topic5", "topic6", "topic7", "topic8", "topic9", "topic10"]] = df.Topic.apply(pd.Series)

    df = df.sort_values(by='Adjusted_Popularity', ascending=False)
    df = df.reset_index(drop=True) #this time we want to get rid of old index, which means nothing post sorting
    
    return df

# %%
winners_df = dict_to_df(winners_dict)
winners_df.head(15)
# Out:
#     Topic Number  Adjusted_Popularity  \
# 0             28         16465623.054
# 1             41           526719.440
# 2             23           494236.068
# 3              3           391551.864
# 4             26           230235.304
# 5             43           220462.909
# 6             18           189346.054
# 7             48           188011.679
# 8             24           175960.006
# 9             29           172425.614
# 10            31           166547.463
# 11            39           157506.251
# 12            46           142933.852
# 13            50           128287.970
# 14            37           127633.700
#
#                                                 Topic  \
# 0   [(transportation, 0.0493422015093), (plans, 0....
# 1   [(service, 0.0872627144419), (requests, 0.0350...
# 2   [(police, 0.0495996521003), (user, 0.032265367...
# 3   [(transportation, 0.164542015423), (traffic, 0...
# 4   [(public, 0.168381768411), (safety, 0.13998228...
# 5   [(state, 0.175638296746), (new, 0.133403517998...
# 6   [(column, 0.0634273088776), (update, 0.0466752...
# 7   [(business, 0.0803271304597), (license, 0.0323...
# 8   [(official, 0.0610942909105), (account, 0.0497...
# 9   [(planning, 0.0609328856062), (county, 0.05924...
# 10  [(politics, 0.110698260148), (government, 0.09...
# 11  [(health, 0.305311895849), (san, 0.06110177203...
# 12  [(address, 0.0425142976586), (name, 0.02889526...
# 13  [(program, 0.032511463571), (employees, 0.0289...
# 14  [(financial, 0.0959611006916), (permits, 0.066...
#
#                                topic1                         topic2  \
# 0   (transportation, 0.0493422015093)       (plans, 0.0463408207807)
# 1          (service, 0.0872627144419)    (requests, 0.0350316945429)
# 2           (police, 0.0495996521003)        (user, 0.0322653671005)
# 3    (transportation, 0.164542015423)     (traffic, 0.0382494150922)
# 4            (public, 0.168381768411)       (safety, 0.139982283853)
# 5             (state, 0.175638296746)          (new, 0.133403517998)
# 6           (column, 0.0634273088776)      (update, 0.0466752365795)
# 7         (business, 0.0803271304597)      (license, 0.032302648157)
# 8         (official, 0.0610942909105)     (account, 0.0497660475395)
# 9         (planning, 0.0609328856062)      (county, 0.0592460462606)
# 10         (politics, 0.110698260148)  (government, 0.0983150505736)
# 11           (health, 0.305311895849)         (san, 0.0611017720363)
# 12         (address, 0.0425142976586)         (name, 0.028895265436)
# 13          (program, 0.032511463571)   (employees, 0.0289751722757)
# 14       (financial, 0.0959611006916)     (permits, 0.0668632739602)
#
#                            topic3                                     topic4  \
# 0         (iowa, 0.0372400214617)                     (area, 0.031583902009)
# 1   (inspection, 0.0326789351929)             (inspections, 0.0313503518264)
# 2    (information, 0.02962646057)                    (page, 0.0244358789937)
# 3       (street, 0.0297088546702)                 (parking, 0.0260484479646)
# 4        (crime, 0.0631808672948)                    (police, 0.03597164994)
# 5       (michigan, 0.10266572561)                    (york, 0.0777270773871)
# 6     (homeless, 0.0416639506669)                (annually, 0.0300723765516)
# 7          (job, 0.0220026249885)               (contracts, 0.0219341654552)
# 8     (accounts, 0.0483014586496)  ((openmichigan@michigan, 0.0408207146959)
# 9     (district, 0.0590822346049)               (districts, 0.0460914886485)
# 10    (election, 0.0382597777507)                (campaign, 0.0309485620342)
# 11      (county, 0.0586392706518)                    (care, 0.0280055059751)
# 12      (number, 0.0260959266214)                (facility, 0.0211950547561)
# 13       (adult, 0.0244085054991)                (employee, 0.0242968020528)
# 14    (building, 0.0631953900546)                   (permit, 0.054456521697)
#
#                               topic5                         topic6  \
# 0         (transit, 0.0297466527633)   (operations, 0.029650998681)
# 1             (311, 0.0263119431044)       (public, 0.025968462717)
# 2      (department, 0.0237288839327)          (use, 0.023314363269)
# 3   (infrastructure, 0.024499661836)        (city, 0.0242484880067)
# 4      (department, 0.0193424493246)    (illinois, 0.0152118075546)
# 5     (information, 0.0292838745522)       (check, 0.0203220904165)
# 6       (frequency, 0.0292689424963)     (position, 0.021127522302)
# 7      (businesses, 0.0197708503312)      (vendor, 0.0178329754117)
# 8         (special, 0.0291639985893)      (nursing, 0.028770388416)
# 9      (boundaries, 0.0372114905902)         (city, 0.029524721059)
# 10      (elections, 0.0296823051034)  (commission, 0.0293149928715)
# 11       (counties, 0.0199253952569)      (system, 0.0163770295818)
# 12        (patient, 0.0187283290738)    (location, 0.0173565095563)
# 13         (annual, 0.0204986126128)       (names, 0.0182179413533)
# 14   (expenditures, 0.0429247389481)       (guide, 0.0250580534259)
#
#                              topic7                           topic8  \
# 0         (region, 0.0286308933708)           (bus, 0.0239404049245)
# 1     (violations, 0.0237687923195)        (request, 0.022587674832)
# 2        (orleans, 0.0183127709217)        (injury, 0.0174977535732)
# 3           (safe, 0.0239084069945)       (vehicle, 0.0231351100665)
# 4           (race, 0.0133652012852)       (reported, 0.011776909211)
# 5   (measurements, 0.0197080431536)          (jobs, 0.0170402721275)
# 6            (city, 0.019841539727)    (commercial, 0.0184651409887)
# 7          (owned, 0.0175281633585)      (contract, 0.0175169967387)
# 8       (software, 0.0268065464462)            (gis, 0.023974220834)
# 9          (areas, 0.0270950065527)        (zoning, 0.0266346423368)
# 10       (results, 0.0249283166716)          (city, 0.0213278569983)
# 11    (facilities, 0.0140076033687)       (network, 0.0135614573066)
# 12      (contains, 0.0147027345652)          (type, 0.0140782421165)
# 13          (full, 0.0179091183965)         (abuse, 0.0162096834129)
# 14        (issued, 0.0232434329642)  (construction, 0.0228846174877)
#
#                             topic9                       topic10
# 0      (priority, 0.0197652573751)     (people, 0.0157596265395)
# 1    (complaints, 0.0193704153109)       (days, 0.0180026003213)
# 2           (may, 0.0166580734835)    (records, 0.0131997374277)
# 3       (streets, 0.0219852292388)       (bike, 0.0155102577616)
# 4        (crimes, 0.0115504690759)   (criminal, 0.0105105785255)
# 5     (licensing, 0.0169768940674)         (ny, 0.0167776417369)
# 6         (daily, 0.0168690536946)   (salaries, 0.0155892433715)
# 7      (licenses, 0.0169698891758)  (certified, 0.0166884614561)
# 8           (use, 0.0225286064837)   (consumer, 0.0224473950606)
# 9           (gis, 0.0244396763289)    (council, 0.0230826924938)
# 10          (460, 0.0200805489271)    (finance, 0.0197352160164)
# 11         (home, 0.0112061646845)  (francisco, 0.0103104720032)
# 12             (g, 0.013900974383)   (transfer, 0.0138993318674)
# 13    (nutrition, 0.0157677124596)  (beginning, 0.0142137708217)
# 14  (information, 0.0227968624179)      (filter, 0.021954851646)

# %% [markdown]
# ### Results:
# - "Transportation Planning and Operations" predominates. Another transportation dataset -- something that I would call "Personal Transportation" -- parking, traffic, vehicle, and even bike -- is also the fourth most popular by this metric. Between these two topics, it's safe to conclude transportation datasets are very popular.
# - Likewise with a "Police Information and Records" and "Crime Reports" topics, which place 3 and 5 respectively.
# - The metrics for rankings 2, 3, and 4 are very close, and could easily change based on how we tweak our metrics. Let's see.

# %% [markdown]
# ## "Winner Take All with Thresholds" Rules:
# - **Scoring Rules:**
#     - Same as "Winner Take All", except a winning topic must compose at least a certain threshold of a document to get any points.
#     - We'll try 0.2 (low) and 0.5 (high) thresholds.

# %%
def winner_take_all_thresholds(df, thresh):
    results_dict = {}
    df = df.fillna(0) #make sure we have a clean df
    
    if thresh == "low":
        for row_num in df.index:
            tup_list = df.topic_comp[row_num] #list of (topic, doc composition) tuples
        
            #neat little trick to return only the tuple w/highest index[1] value
            winner_tuple = max(tup_list, key=lambda item:item[1])  
            
            if not winner_tuple[0] in results_dict: #if not in dict, add it with its score
                if winner_tuple[1] > 0.2:
                    results_dict[winner_tuple[0]] = (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
            else:
                pass
        
            if winner_tuple[0] in results_dict: #if in dict, increment that key's value with score
                if winner_tuple[1] > 0.2:
                    results_dict[winner_tuple[0]] += (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
            else:
                pass
                
    if thresh == "high":
        for row_num in df.index:
            tup_list = df.topic_comp[row_num] #list of (topic, doc composition) tuples
        
            #neat little trick to return only the tuple w/highest index[1] value
            winner_tuple = max(tup_list, key=lambda item:item[1])  
            
            if not winner_tuple[0] in results_dict: #if not in dict, add it with its score
                if winner_tuple[1] > 0.5:
                    results_dict[winner_tuple[0]] = (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
            else:
                pass
        
            if winner_tuple[0] in results_dict: #if in dict, increment that key's value with score
                if winner_tuple[1] > 0.5:
                    results_dict[winner_tuple[0]] += (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
            else:
                pass

    return results_dict

# %%
low = winner_take_all_thresholds(topics, thresh='low')

# %%
low_thresh_ranks = dict_to_df(low)

# %%
low_thresh_ranks.head(10)
# Out:
#    Topic Number  Adjusted_Popularity  \
# 0            28         16461078.655
# 1            41           518910.864
# 2            23           493161.782
# 3             3           325695.778
# 4            26           219560.730
# 5            43           208198.844
# 6            18           188072.809
# 7            48           181698.149
# 8            24           172835.501
# 9            29           170112.755
#
#                                                Topic  \
# 0  [(transportation, 0.0493422015093), (plans, 0....
# 1  [(service, 0.0872627144419), (requests, 0.0350...
# 2  [(police, 0.0495996521003), (user, 0.032265367...
# 3  [(transportation, 0.164542015423), (traffic, 0...
# 4  [(public, 0.168381768411), (safety, 0.13998228...
# 5  [(state, 0.175638296746), (new, 0.133403517998...
# 6  [(column, 0.0634273088776), (update, 0.0466752...
# 7  [(business, 0.0803271304597), (license, 0.0323...
# 8  [(official, 0.0610942909105), (account, 0.0497...
# 9  [(planning, 0.0609328856062), (county, 0.05924...
#
#                               topic1                       topic2  \
# 0  (transportation, 0.0493422015093)     (plans, 0.0463408207807)
# 1         (service, 0.0872627144419)  (requests, 0.0350316945429)
# 2          (police, 0.0495996521003)      (user, 0.0322653671005)
# 3   (transportation, 0.164542015423)   (traffic, 0.0382494150922)
# 4           (public, 0.168381768411)     (safety, 0.139982283853)
# 5            (state, 0.175638296746)        (new, 0.133403517998)
# 6          (column, 0.0634273088776)    (update, 0.0466752365795)
# 7        (business, 0.0803271304597)    (license, 0.032302648157)
# 8        (official, 0.0610942909105)   (account, 0.0497660475395)
# 9        (planning, 0.0609328856062)    (county, 0.0592460462606)
#
#                           topic3                                     topic4  \
# 0        (iowa, 0.0372400214617)                     (area, 0.031583902009)
# 1  (inspection, 0.0326789351929)             (inspections, 0.0313503518264)
# 2   (information, 0.02962646057)                    (page, 0.0244358789937)
# 3      (street, 0.0297088546702)                 (parking, 0.0260484479646)
# 4       (crime, 0.0631808672948)                    (police, 0.03597164994)
# 5      (michigan, 0.10266572561)                    (york, 0.0777270773871)
# 6    (homeless, 0.0416639506669)                (annually, 0.0300723765516)
# 7         (job, 0.0220026249885)               (contracts, 0.0219341654552)
# 8    (accounts, 0.0483014586496)  ((openmichigan@michigan, 0.0408207146959)
# 9    (district, 0.0590822346049)               (districts, 0.0460914886485)
#
#                              topic5                        topic6  \
# 0        (transit, 0.0297466527633)  (operations, 0.029650998681)
# 1            (311, 0.0263119431044)      (public, 0.025968462717)
# 2     (department, 0.0237288839327)         (use, 0.023314363269)
# 3  (infrastructure, 0.024499661836)       (city, 0.0242484880067)
# 4     (department, 0.0193424493246)   (illinois, 0.0152118075546)
# 5    (information, 0.0292838745522)      (check, 0.0203220904165)
# 6      (frequency, 0.0292689424963)    (position, 0.021127522302)
# 7     (businesses, 0.0197708503312)     (vendor, 0.0178329754117)
# 8        (special, 0.0291639985893)     (nursing, 0.028770388416)
# 9     (boundaries, 0.0372114905902)        (city, 0.029524721059)
#
#                             topic7                         topic8  \
# 0        (region, 0.0286308933708)         (bus, 0.0239404049245)
# 1    (violations, 0.0237687923195)      (request, 0.022587674832)
# 2       (orleans, 0.0183127709217)      (injury, 0.0174977535732)
# 3          (safe, 0.0239084069945)     (vehicle, 0.0231351100665)
# 4          (race, 0.0133652012852)     (reported, 0.011776909211)
# 5  (measurements, 0.0197080431536)        (jobs, 0.0170402721275)
# 6           (city, 0.019841539727)  (commercial, 0.0184651409887)
# 7         (owned, 0.0175281633585)    (contract, 0.0175169967387)
# 8      (software, 0.0268065464462)          (gis, 0.023974220834)
# 9         (areas, 0.0270950065527)      (zoning, 0.0266346423368)
#
#                           topic9                       topic10
# 0    (priority, 0.0197652573751)     (people, 0.0157596265395)
# 1  (complaints, 0.0193704153109)       (days, 0.0180026003213)
# 2         (may, 0.0166580734835)    (records, 0.0131997374277)
# 3     (streets, 0.0219852292388)       (bike, 0.0155102577616)
# 4      (crimes, 0.0115504690759)   (criminal, 0.0105105785255)
# 5   (licensing, 0.0169768940674)         (ny, 0.0167776417369)
# 6       (daily, 0.0168690536946)   (salaries, 0.0155892433715)
# 7    (licenses, 0.0169698891758)  (certified, 0.0166884614561)
# 8         (use, 0.0225286064837)   (consumer, 0.0224473950606)
# 9         (gis, 0.0244396763289)    (council, 0.0230826924938)

# %% [markdown]
# ### Interesting. The calculated scores haven't changed that much, but they have moved by a few thousand in many cases.
#
# We can see from this that how you score matters. Let's see how much by setting a very high affinity threshold:

# %%
high = winner_take_all_thresholds(topics, thresh='high')

# %%
high_thresh_ranks = dict_to_df(high)

# %%
high_thresh_ranks.head(10)
# Out:
#    Topic Number  Adjusted_Popularity  \
# 0            28         15956210.504
# 1            23           449272.292
# 2            41           275563.717
# 3            24           136515.744
# 4            43           102284.078
# 5            31            92203.533
# 6            46            70784.204
# 7            26            63222.136
# 8            32            56775.321
# 9            50            56295.097
#
#                                                Topic  \
# 0  [(transportation, 0.0493422015093), (plans, 0....
# 1  [(police, 0.0495996521003), (user, 0.032265367...
# 2  [(service, 0.0872627144419), (requests, 0.0350...
# 3  [(official, 0.0610942909105), (account, 0.0497...
# 4  [(state, 0.175638296746), (new, 0.133403517998...
# 5  [(politics, 0.110698260148), (government, 0.09...
# 6  [(address, 0.0425142976586), (name, 0.02889526...
# 7  [(public, 0.168381768411), (safety, 0.13998228...
# 8  [(open, 0.111361606245), (created, 0.066633337...
# 9  [(program, 0.032511463571), (employees, 0.0289...
#
#                               topic1                         topic2  \
# 0  (transportation, 0.0493422015093)       (plans, 0.0463408207807)
# 1          (police, 0.0495996521003)        (user, 0.0322653671005)
# 2         (service, 0.0872627144419)    (requests, 0.0350316945429)
# 3        (official, 0.0610942909105)     (account, 0.0497660475395)
# 4            (state, 0.175638296746)          (new, 0.133403517998)
# 5         (politics, 0.110698260148)  (government, 0.0983150505736)
# 6         (address, 0.0425142976586)         (name, 0.028895265436)
# 7           (public, 0.168381768411)       (safety, 0.139982283853)
# 8             (open, 0.111361606245)     (created, 0.0666333370863)
# 9          (program, 0.032511463571)   (employees, 0.0289751722757)
#
#                           topic3                                     topic4  \
# 0        (iowa, 0.0372400214617)                     (area, 0.031583902009)
# 1   (information, 0.02962646057)                    (page, 0.0244358789937)
# 2  (inspection, 0.0326789351929)             (inspections, 0.0313503518264)
# 3    (accounts, 0.0483014586496)  ((openmichigan@michigan, 0.0408207146959)
# 4      (michigan, 0.10266572561)                    (york, 0.0777270773871)
# 5    (election, 0.0382597777507)                (campaign, 0.0309485620342)
# 6      (number, 0.0260959266214)                (facility, 0.0211950547561)
# 7       (crime, 0.0631808672948)                    (police, 0.03597164994)
# 8       (items, 0.0469751568036)                   (clear, 0.0249716560821)
# 9       (adult, 0.0244085054991)                (employee, 0.0242968020528)
#
#                            topic5                         topic6  \
# 0      (transit, 0.0297466527633)   (operations, 0.029650998681)
# 1   (department, 0.0237288839327)          (use, 0.023314363269)
# 2          (311, 0.0263119431044)       (public, 0.025968462717)
# 3      (special, 0.0291639985893)      (nursing, 0.028770388416)
# 4  (information, 0.0292838745522)       (check, 0.0203220904165)
# 5    (elections, 0.0296823051034)  (commission, 0.0293149928715)
# 6      (patient, 0.0187283290738)    (location, 0.0173565095563)
# 7   (department, 0.0193424493246)    (illinois, 0.0152118075546)
# 8       (volume, 0.0175690284296)      (please, 0.0162081895116)
# 9       (annual, 0.0204986126128)       (names, 0.0182179413533)
#
#                             topic7                        topic8  \
# 0        (region, 0.0286308933708)        (bus, 0.0239404049245)
# 1       (orleans, 0.0183127709217)     (injury, 0.0174977535732)
# 2    (violations, 0.0237687923195)     (request, 0.022587674832)
# 3      (software, 0.0268065464462)         (gis, 0.023974220834)
# 4  (measurements, 0.0197080431536)       (jobs, 0.0170402721275)
# 5       (results, 0.0249283166716)       (city, 0.0213278569983)
# 6      (contains, 0.0147027345652)       (type, 0.0140782421165)
# 7          (race, 0.0133652012852)    (reported, 0.011776909211)
# 8      (presented, 0.015509271243)  (difficult, 0.0141524865491)
# 9          (full, 0.0179091183965)      (abuse, 0.0162096834129)
#
#                           topic9                       topic10
# 0    (priority, 0.0197652573751)     (people, 0.0157596265395)
# 1         (may, 0.0166580734835)    (records, 0.0131997374277)
# 2  (complaints, 0.0193704153109)       (days, 0.0180026003213)
# 3         (use, 0.0225286064837)   (consumer, 0.0224473950606)
# 4   (licensing, 0.0169768940674)         (ny, 0.0167776417369)
# 5         (460, 0.0200805489271)    (finance, 0.0197352160164)
# 6            (g, 0.013900974383)   (transfer, 0.0138993318674)
# 7      (crimes, 0.0115504690759)   (criminal, 0.0105105785255)
# 8    (potential, 0.013902418106)       (note, 0.0129587647759)
# 9   (nutrition, 0.0157677124596)  (beginning, 0.0142137708217)

# %% [markdown]
# **This is very interesting. Our main transportation tag still reigns, but the other transportation tag has fallen completely out of the top 10! Our 311 topic tag still hangs in there, but falls to third versus police records. We can draw a few conclusions from this:**
# - Transportation, 311/service calls, and police records are resilient; they remain popular across calculations.
# - Other tags shift rankings significantly. We should be careful about drawing sweeping conclusions from ranks 4-10.
#     - To begin with, we've sacrificed interpretability to reduce variance in our adjusted popularity calculation. We don't want total views to make NYC datasets the "most popular". But by summing log views and downloads, and taking a portion of those views, we've lost some ability to interpret absolute differences in our calculations. A human knows the difference between 1000 views and 10 views; what's the difference between 100,095 adjusted popularity and 92,203? It's not intuitive.
#     - These results don't mean "release this open dataset 3rd, then this 4th, etc. It's just a guide to a snapshot of Socrata data at a certain point in time. **As noted, however, it is safe to conclude that transportation plans and operations, along with police records and 311 data, are datasets the public accesses frequently.**
# - Our "catch all" tags seem to get more popular with a stricter cut off. I think it's possible that they match parochial datasets very well, but match fewer datasets as a winner overall. Topics that actually tell us something but are more broad may match datasets less well, but match more (at a 0.3-0.4 threshold), therefore losing some credit with a stricter threshold. This is just speculation, however.

# %% [markdown]
# ### Let's a method of calculating wherein a dataset can get "partial credit", as long as it's above a certain threshold.
# - Datasets get their share of combined log views + downloads, as long as they compose at least 0.2 of a document.

# %%
def calc_proportional_pop(df):
    df = df.fillna(0)
    results_dict = {}
    
    for row_num in df.index:
        for tup in df.topic_comp[row_num]: #no need to pick a winner here...
            if not tup[0] in results_dict:
                if tup[1] >= 0.2: #.loc interprets as the label of the index, not int position
                    results_dict[tup[0]] = (tup[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
                else:
                    pass
            if tup[0] in results_dict:
                if tup[1] >= 0.2:
                    results_dict[tup[0]] += (tup[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total_log))
    return results_dict

# %%
proportions = calc_proportional_pop(topics) #pretty sure .loc makes this slower than using .iloc

# %%
proportional_pop_df = dict_to_df(proportions)

# %%
proportional_pop_df.head(15)
# Out:
#     Topic Number  Adjusted_Popularity  \
# 0             28         16478738.222
# 1             41           586779.754
# 2             23           502600.191
# 3              3           359881.938
# 4             31           251066.127
# 5             26           249091.564
# 6             43           241684.562
# 7             29           233415.749
# 8             24           222915.660
# 9             48           204355.994
# 10            18           194450.466
# 11            34           179703.511
# 12            37           172488.703
# 13            49           149059.120
# 14            46           148932.095
#
#                                                 Topic  \
# 0   [(transportation, 0.0493422015093), (plans, 0....
# 1   [(service, 0.0872627144419), (requests, 0.0350...
# 2   [(police, 0.0495996521003), (user, 0.032265367...
# 3   [(transportation, 0.164542015423), (traffic, 0...
# 4   [(politics, 0.110698260148), (government, 0.09...
# 5   [(public, 0.168381768411), (safety, 0.13998228...
# 6   [(state, 0.175638296746), (new, 0.133403517998...
# 7   [(planning, 0.0609328856062), (county, 0.05924...
# 8   [(official, 0.0610942909105), (account, 0.0497...
# 9   [(business, 0.0803271304597), (license, 0.0323...
# 10  [(column, 0.0634273088776), (update, 0.0466752...
# 11  [(education, 0.181504757587), (school, 0.08185...
# 12  [(financial, 0.0959611006916), (permits, 0.066...
# 13  [(development, 0.176027756751), (housing, 0.15...
# 14  [(address, 0.0425142976586), (name, 0.02889526...
#
#                                topic1                         topic2  \
# 0   (transportation, 0.0493422015093)       (plans, 0.0463408207807)
# 1          (service, 0.0872627144419)    (requests, 0.0350316945429)
# 2           (police, 0.0495996521003)        (user, 0.0322653671005)
# 3    (transportation, 0.164542015423)     (traffic, 0.0382494150922)
# 4          (politics, 0.110698260148)  (government, 0.0983150505736)
# 5            (public, 0.168381768411)       (safety, 0.139982283853)
# 6             (state, 0.175638296746)          (new, 0.133403517998)
# 7         (planning, 0.0609328856062)      (county, 0.0592460462606)
# 8         (official, 0.0610942909105)     (account, 0.0497660475395)
# 9         (business, 0.0803271304597)      (license, 0.032302648157)
# 10          (column, 0.0634273088776)      (update, 0.0466752365795)
# 11        (education, 0.181504757587)      (school, 0.0818576925692)
# 12       (financial, 0.0959611006916)     (permits, 0.0668632739602)
# 13      (development, 0.176027756751)      (housing, 0.152212657649)
# 14         (address, 0.0425142976586)         (name, 0.028895265436)
#
#                            topic3                                     topic4  \
# 0         (iowa, 0.0372400214617)                     (area, 0.031583902009)
# 1   (inspection, 0.0326789351929)             (inspections, 0.0313503518264)
# 2    (information, 0.02962646057)                    (page, 0.0244358789937)
# 3       (street, 0.0297088546702)                 (parking, 0.0260484479646)
# 4     (election, 0.0382597777507)                (campaign, 0.0309485620342)
# 5        (crime, 0.0631808672948)                    (police, 0.03597164994)
# 6       (michigan, 0.10266572561)                    (york, 0.0777270773871)
# 7     (district, 0.0590822346049)               (districts, 0.0460914886485)
# 8     (accounts, 0.0483014586496)  ((openmichigan@michigan, 0.0408207146959)
# 9          (job, 0.0220026249885)               (contracts, 0.0219341654552)
# 10    (homeless, 0.0416639506669)                (annually, 0.0300723765516)
# 11     (schools, 0.0317766682176)                (students, 0.0295716293995)
# 12    (building, 0.0631953900546)                   (permit, 0.054456521697)
# 13    (economic, 0.0588541094432)               (community, 0.0485919430535)
# 14      (number, 0.0260959266214)                (facility, 0.0211950547561)
#
#                                topic5                         topic6  \
# 0          (transit, 0.0297466527633)   (operations, 0.029650998681)
# 1              (311, 0.0263119431044)       (public, 0.025968462717)
# 2       (department, 0.0237288839327)          (use, 0.023314363269)
# 3    (infrastructure, 0.024499661836)        (city, 0.0242484880067)
# 4        (elections, 0.0296823051034)  (commission, 0.0293149928715)
# 5       (department, 0.0193424493246)    (illinois, 0.0152118075546)
# 6      (information, 0.0292838745522)       (check, 0.0203220904165)
# 7       (boundaries, 0.0372114905902)         (city, 0.029524721059)
# 8          (special, 0.0291639985893)      (nursing, 0.028770388416)
# 9       (businesses, 0.0197708503312)      (vendor, 0.0178329754117)
# 10       (frequency, 0.0292689424963)     (position, 0.021127522302)
# 11          (public, 0.0171734235818)  (governance, 0.0167833173256)
# 12    (expenditures, 0.0429247389481)       (guide, 0.0250580534259)
# 13  (infrastructure, 0.0190401252932)     (managed, 0.0183046960354)
# 14         (patient, 0.0187283290738)    (location, 0.0173565095563)
#
#                              topic7                           topic8  \
# 0         (region, 0.0286308933708)           (bus, 0.0239404049245)
# 1     (violations, 0.0237687923195)        (request, 0.022587674832)
# 2        (orleans, 0.0183127709217)        (injury, 0.0174977535732)
# 3           (safe, 0.0239084069945)       (vehicle, 0.0231351100665)
# 4        (results, 0.0249283166716)          (city, 0.0213278569983)
# 5           (race, 0.0133652012852)       (reported, 0.011776909211)
# 6   (measurements, 0.0197080431536)          (jobs, 0.0170402721275)
# 7          (areas, 0.0270950065527)        (zoning, 0.0266346423368)
# 8       (software, 0.0268065464462)            (gis, 0.023974220834)
# 9          (owned, 0.0175281633585)      (contract, 0.0175169967387)
# 10           (city, 0.019841539727)    (commercial, 0.0184651409887)
# 11         (state, 0.0165785793709)          (year, 0.0161596047936)
# 12        (issued, 0.0232434329642)  (construction, 0.0228846174877)
# 13      (medicaid, 0.0178764063515)    (department, 0.0140238290886)
# 14      (contains, 0.0147027345652)          (type, 0.0140782421165)
#
#                             topic9                       topic10
# 0      (priority, 0.0197652573751)     (people, 0.0157596265395)
# 1    (complaints, 0.0193704153109)       (days, 0.0180026003213)
# 2           (may, 0.0166580734835)    (records, 0.0131997374277)
# 3       (streets, 0.0219852292388)       (bike, 0.0155102577616)
# 4           (460, 0.0200805489271)    (finance, 0.0197352160164)
# 5        (crimes, 0.0115504690759)   (criminal, 0.0105105785255)
# 6     (licensing, 0.0169768940674)         (ny, 0.0167776417369)
# 7           (gis, 0.0244396763289)    (council, 0.0230826924938)
# 8           (use, 0.0225286064837)   (consumer, 0.0224473950606)
# 9      (licenses, 0.0169698891758)  (certified, 0.0166884614561)
# 10        (daily, 0.0168690536946)   (salaries, 0.0155892433715)
# 11      (student, 0.0161397342546)   (district, 0.0160036278832)
# 12  (information, 0.0227968624179)      (filter, 0.021954851646)
# 13    (buildings, 0.0137754059922)    (economy, 0.0123473943134)
# 14             (g, 0.013900974383)   (transfer, 0.0138993318674)

# %% [markdown]
# ### These are intuitive results. Our top 6 topics are clean and interpretable, and pass a gut-check in terms of what citizens might search and view.
# - However, there is really not much separating topics 5-10 (again, small differences in magnitude in our adjusted popularity metric don't tell us much).
# - Transportation, police records, and 311 are still atop the heap. **However, our second transportation category comes all the way back to #4;** I'd bet that this is because it's often second place to the more popular transportation topic in the winner-take-all format.
# - I would argue this is the best format for scoring; **some datasets really do, to the human eye, fit into two (or three or four!) topic tags**. This also dilutes model error in which the "winner" doesn't really match the dataset according to the human eye; a dataset that does can still get partial credit.
# - However, you can make an argument for only winner topics of high affinity. This type of probabilistic analysis is always going to have assumptions - it's just important to note them.

# %% [markdown]
# # Top Topic Tags by Domain
# - Let's see if the most popular topics vary by city/state. We can use "domain" -- the web address of an open data portal -- to sort them.

# %%
def popularity_by_domain(df, domain_name):
    
    domain_df = df[df.domain == domain_name]
    popularity_dict = calc_proportional_pop(domain_df) #we're still using our proportional scoring here
    
    df_pop = pd.DataFrame.from_dict(popularity_dict, orient='index') #dict is in df but index numbers (aka topic numbers) are random
    df_pop = df_pop.rename(index=int, columns={0:"Adjusted_Popularity"})
    
    topic_words_list = []
    for topic_num in df_pop.index: #this iterates in the right order - index numbers have real meaning
        topic_tups = lda_52_sixty.show_topic(topic_num)
        raw_words = list(i[0] for i in lda_52_sixty.show_topic(topic_num))
        string = ", ".join(raw_words)
        topic_words_list.append(string) #plug in names by index numbers
    
    df_pop['Topic_Words'] = topic_words_list
    
    df_pop = df_pop.sort_values(by='Adjusted_Popularity', ascending=False)
    
    #put the domain in each row - kind of an ugly way to preserve info about domain but it's what we've got
    domain_string = domain_name
    df_pop['Domain'] = [domain_string for number in range(len(df_pop.index))]
    
    return df_pop

# %%
madison = popularity_by_domain(topics, "data.cityofmadison.com")

# %%
madison
# Out:
#     Adjusted_Popularity                                        Topic_Words  \
# 31             3925.956  politics, government, election, campaign, elec...
# 21             3087.734  public, safety, fire, month, calls, police, em...
# 26             2661.438  public, safety, crime, police, department, ill...
# 49             2649.683  development, housing, economic, community, inf...
# 0              1713.837  prevention, hospital, ny, healthy, statewide, ...
# 12             1133.078  map, "about", shows, details, tracking, click,...
# 42              832.791  information, list, code, required, political, ...
# 1               661.705  chart, children, income, historic, home, assis...
# 9               559.380  recreation, parks, jersey, park, center, neigh...
# 41              391.758  service, requests, inspection, inspections, 31...
# 22              347.438  arts, grants, live, county, includes, library,...
# 3               332.834  transportation, traffic, street, parking, infr...
# 46              268.104  address, name, number, facility, patient, loca...
# 27              258.333  water, environment, protection, tx, filed, was...
# 29              245.204  planning, county, district, districts, boundar...
# 17              225.303  services, social, human, dfps, information, pr...
# 39              225.303  health, san, county, care, counties, system, f...
# 45              209.611  report, performance, city, goal, resultsnola, ...
# 30              181.872  mateo, city, gis, land, county, parcel, map, p...
# 25              174.766  tax, revenue, sales, taxes, local, colorado, g...
# 5               156.966  locations, bacteria, hours, culture, county, l...
# 28               97.956  transportation, plans, iowa, area, transit, op...
#
#                     Domain
# 31  data.cityofmadison.com
# 21  data.cityofmadison.com
# 26  data.cityofmadison.com
# 49  data.cityofmadison.com
# 0   data.cityofmadison.com
# 12  data.cityofmadison.com
# 42  data.cityofmadison.com
# 1   data.cityofmadison.com
# 9   data.cityofmadison.com
# 41  data.cityofmadison.com
# 22  data.cityofmadison.com
# 3   data.cityofmadison.com
# 46  data.cityofmadison.com
# 27  data.cityofmadison.com
# 29  data.cityofmadison.com
# 17  data.cityofmadison.com
# 39  data.cityofmadison.com
# 45  data.cityofmadison.com
# 30  data.cityofmadison.com
# 25  data.cityofmadison.com
# 5   data.cityofmadison.com
# 28  data.cityofmadison.com

# %% [markdown]
# Interesting! By our log measures, politics is the most popular topic in Madison. Makes sense.

# %% [markdown]
# ### Finally, by this scoring, let's return all topics that formed a top topic and the city's they were top in:

# %%
def top_topics_by_domain(df, domains_series):
    
    domains_dict = {}
    for domain in domains_series:
        
        domain_df = popularity_by_domain(df, domain) #this is a df like the Madison example
        Topic = domain_df.iloc[0].Topic_Words #string
        Domain = domain_df.iloc[0].Domain.split() #have to remember to split(), which really just gives us one word
        
        if Topic in domains_dict: 
            domains_dict[Topic] += Domain
        else:
            domains_dict[Topic] = list(Domain)
    
    return domains_dict

# %% [markdown]
# (This takes a bit to run since we are slicing df's for 140+ domains and iterating through them. There's probably a better way.)

# %%
all_domains = topics.domain.unique()
top_topic_domains = top_topics_by_domain(topics, domains_series=all_domains)

# %%
top_topic_domains
# Out:
# {'budget, finance, fund, year, operating, city, fiscal, funds, calendar, communities': ['data.smcgov.org',
#   'data.tompsc.com',
#   'data.topeka.org',
#   'data.vbgov.com',
#   'information.stpaul.gov',
#   'performance.ci.janesville.wi.us'],
#  'business, license, job, contracts, businesses, vendor, owned, contract, licenses, certified': ['data.auburnwa.gov',
#   'data.cityofgainesville.org',
#   'data.culvercity.org',
#   'data.hampton.gov',
#   'data.oregon.gov',
#   'data.oxnard.org',
#   'opendata.cityofhenderson.com',
#   'opendata.lasvegasnevada.gov'],
#  'care, finance, provider, child, cost, plan, day, bay, government, fee': ['data.detroitmi.gov'],
#  'census, indicators, survey, includes, indicator, community, demographics, bureau, u, level': ['data.livewellsd.org'],
#  'chart, children, income, historic, home, assistance, homes, families, low, pay': ['data.richmondgov.com'],
#  'column, update, homeless, annually, frequency, position, city, commercial, daily, salaries': ['data.cityofwestsacramento.org',
#   'data.douglas.co.us'],
#  'death, maryland, database, deaths, office, department, new, cdc, metadata, citizens': ['data.maryland.gov'],
#  'development, housing, economic, community, infrastructure, managed, medicaid, department, buildings, economy': ['dashboard.alexandriava.gov',
#   'data.maine.gov',
#   'insights.cincinnati-oh.gov'],
#  'economy, employment, labor, unemployment, insurance, credit, workforce, economic, training, federal': ['data.datamontana.us',
#   'data.hawaii.gov',
#   'data.iowa.gov'],
#  'education, school, schools, students, public, governance, state, year, student, district': ['dashboard.hawaii.gov',
#   'dashboard.slco.org',
#   'data.mass.gov',
#   'data.pa.gov',
#   'data.vermont.gov',
#   'impact.stlouisco.com'],
#  'energy, environment, electricity, air, sustainable, action, climate, city, clean, facilities': ['data.monroecounty-fl.gov',
#   'data.results.wa.gov',
#   'data.sustainablesm.org',
#   'performance.providenceri.gov'],
#  'finance, year, state, monthly, fiscal, payments, government, june, july, report': ['data.cstx.gov',
#   'data.nj.gov',
#   'data.oaklandnet.com',
#   'datacatalog.cookcountyil.gov',
#   'opencheckbook.data.somervillema.gov',
#   'performance.cookcountyil.gov',
#   'transparency.michigan.gov'],
#  'financial, permits, building, permit, expenditures, guide, issued, construction, information, filter': ['data.brla.gov',
#   'data.burlingtonvt.gov',
#   'data.menlopark.org',
#   'data.montgomeryal.gov',
#   'data.nashville.gov',
#   'data.seattle.gov',
#   'data.tuscaloosa.com'],
#  'health, disease, 000, per, rate, rates, chronic, risk, agency, due': ['healthdata.nj.gov'],
#  'health, san, county, care, counties, system, facilities, network, home, francisco': ['data.mo.gov',
#   'health.data.ny.gov'],
#  'information, tab, projects, concerning, may, contains, project, provided, additional, improvement': ['data.countyofriverside.us',
#   'data.lcb.wa.gov',
#   'data.qac.org'],
#  'infrastructure, city, public, maps, works, dallas, los, angeles, types, way': ['data.albanyny.gov',
#   'data.cityofboston.gov',
#   'data.cityofevanston.org',
#   'data.jacksonms.gov',
#   'data.weho.org'],
#  'mateo, city, gis, land, county, parcel, map, point, survey, feature': ['data.austintexas.gov'],
#  'measures, quality, performance, government, life, developed, fair, measurement, definitions, index': ['performance.fultoncountyga.gov',
#   'performance.smcgov.org',
#   'performance.topeka.org'],
#  'plan, strategic, master, community, fewer, limitations, registry, cause, years, information': ['data.cincinnati-oh.gov'],
#  'planning, county, district, districts, boundaries, city, areas, zoning, gis, council': ['data.acgov.org',
#   'data.lacity.org',
#   'performance.franklintn.gov',
#   'tni.princegeorgescountymd.gov'],
#  'police, user, information, page, department, use, orleans, injury, may, records': ['data.cityofchicago.org',
#   'data.hartford.gov',
#   'data.nola.gov',
#   'data.srcity.org',
#   'data.urbanaillinois.us',
#   'stat.cityofgainesville.org',
#   'www.dallasopendata.com'],
#  'politics, government, election, campaign, elections, commission, results, city, 460, finance': ['dashboard.plano.gov',
#   'data.cityofmadison.com',
#   'data.kingcounty.gov',
#   'data.macoupincountyil.gov',
#   'data.redmond.gov',
#   'datapoints.dallascityhall.com',
#   'electionsdata.kingcounty.gov',
#   'opendata.cityofmesquite.com',
#   'performance.adcogov.org',
#   'performance.glendaleca.gov',
#   'performance.princegeorgescountymd.gov',
#   'performance.seattle.gov',
#   'performance.vbgov.com',
#   'policeview.johnscreekga.gov'],
#  'population, county, demographics, age, total, king, washington, montgomery, number, years': ['data.illinois.gov',
#   'performance.carson.org'],
#  'public, safety, crime, police, department, illinois, race, reported, crimes, criminal': ['data.fortworthtexas.gov',
#   'data.greensboro-nc.gov',
#   'data.honolulu.gov',
#   'data.lacounty.gov',
#   'data.littlerock.gov',
#   'data.providenceri.gov',
#   'data.readingpa.gov',
#   'data.roseville.ca.us',
#   'data.sonomacounty.ca.gov',
#   'data.wa.gov',
#   'kcstat.kcmo.org',
#   'opencity.fcgov.com',
#   'opendata.miamidade.gov',
#   'opendata.utah.gov',
#   'performance.cityofdavenportiowa.com',
#   'performance.danvilleva.gov'],
#  'public, safety, fire, month, calls, police, emergency, response, discharge, incident': ['data.marincounty.org',
#   'data.montgomerycountymd.gov',
#   'data.naperville.il.us',
#   'data.raleighnc.gov',
#   'opendata.ci.richmond.ca.us',
#   'opendata.howardcountymd.gov',
#   'performance.cityofrc.us',
#   'stats.cityofcarrollton.com'],
#  'rates, calculated, rate, year, counts, average, seattle, percent, mortality, number': ['outcomestat.baltimorecity.gov'],
#  'recreation, parks, jersey, park, center, neighborhoods, centers, facilities, environment, access': ['performance.chattanooga.gov'],
#  "report, performance, city, goal, resultsnola, administration, city's, management, key, topeka": ['performance.austintexas.gov',
#   'performance.williamsburgva.gov'],
#  'service, requests, inspection, inspections, 311, public, violations, request, complaints, days': ['data.cityofnewyork.us',
#   'data.delaware.gov',
#   'data.kcmo.org',
#   'data.princegeorgescountymd.gov'],
#  'state, new, michigan, york, information, check, measurements, jobs, licensing, ny': ['data.baltimorecity.gov',
#   'data.michigan.gov',
#   'data.ny.gov',
#   'midashboard.michigan.gov'],
#  'tax, revenue, sales, taxes, local, colorado, government, state, department, sale': ['data.colorado.gov',
#   'data.ct.gov'],
#  'transportation, plans, iowa, area, transit, operations, region, bus, priority, people': ['data.cityofgp.com',
#   'data.texas.gov',
#   'data.vta.org'],
#  'transportation, traffic, street, parking, infrastructure, city, safe, vehicle, streets, bike': ['data.cambridgema.gov',
#   'data.cityoftacoma.org',
#   'data.muni.org',
#   'data.rutlandcitypolice.com',
#   'data.sfgov.org',
#   'data.somervillema.gov',
#   'reports.data.montgomerycountymd.gov']}

# %% [markdown]
# Now we have some additional insights into our top rankings. **Notice that our top topic, "transportation planning and operations" is only the most popular dataset in Texas and a California transit agency (as well as the smaller City of Grand Prairie).** This makes sense -- people in big populated places probably care alot about transportation projects.
#
# This topic is also definitely getting some weight from the fact that Texas and California have high populations and presumably high open data access rates. However, this is why we took the log of views; to dilute the effects of high population.
#
# ### Still, this has us thinking -- let's see if we get different rankings if we sum a topics popularity within *each* city/state, and then log this sum.
# - This will further reduce the weight of city/state open data portals that just get a high number of views and downloads (presumably) by virtue of being a high-population area.

# %% [markdown]
# ## One more scoring setting: Normalize Metrics within a City/State
# ## (Dampened Popularity):
# - Each city/state/organization (as identified by domain) has topics that "win" for each dataset.
# - Add up each's topics "spoils" (total views and downloads) within a given city. THEN take the log of that.
# - Then add up all log totals for each topic across cities.
# - This is an extra control for big cities with lots of users skewing our metrics. **We'll call it dampened popularity.**

# %%
from collections import Counter #need this to sync dictionaries

# %%
def popularity_normalized_by_area(df, domains_series):
    
    df = df.fillna(0) #there are 369 datasets with NaN download counts (no missing view counts)
    #let's assume they're NaN because there were no downloads
    
    list_of_domain_dicts = []
    popularity_dict = {}
    
    for domain in domains_series:
        
        results_dict = {}
        
        #get our df only of rows from a given city/state domain
        domain_df = df[df.domain == domain]
        
        for row_num in domain_df.index:
            tup_list = domain_df.topic_comp[row_num] #list of (topic, doc composition) tuples
        
            #neat little trick to return only the tuple w/highest index[1] value
            winner_tuple = max(tup_list, key=lambda item:item[1])  
            
            if not winner_tuple[0] in results_dict: #if not in dict, add it with its TOTAL VIEWS score
                if winner_tuple[1] > 0.2:
                    results_dict[winner_tuple[0]] = (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total))
            else:
                pass
        
            if winner_tuple[0] in results_dict: #if in dict, increment that key's value with score
                if winner_tuple[1] > 0.2:
                    results_dict[winner_tuple[0]] += (winner_tuple[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total))
            else:
                pass
            
        
        #when loop of domain_df is finished, take log of all keys in dict
        log_dict = {}
        for k,v in results_dict.items():
            if v != 0: #have to do this since you can't take a log of 0; some "winners" get datasets with 0 views
                log_dict[k] = np.log(v)
        
        #now we have a polished dict of topic numbers as keys and log of all views/DLs as values; append it to list
        list_of_domain_dicts.append(log_dict)
    
    #use Counter() object to sync our dictionaries
    c = Counter()
    for d in list_of_domain_dicts:
        c.update(d)
    
    popularity_dict = dict(c)
    
    return popularity_dict

# %%
all_domains = topics.domain.unique()
pop_norm_area_dict = popularity_normalized_by_area(topics, all_domains)

# %%
#pop_norm_area_dict #uncomment just to ensure topic numbers align with topic tags

# %%
#lda_52_sixty.show_topics(num_topics=52, formatted=False)

# %%
norm_by_areas_df = dict_to_df(pop_norm_area_dict)
norm_by_areas_df.head(20)
# Out:
#     Topic Number  Adjusted_Popularity  \
# 0             26              799.492
# 1              3              692.631
# 2             21              670.051
# 3             49              623.113
# 4             37              584.586
# 5             40              582.037
# 6             31              572.482
# 7             48              560.589
# 8             41              499.286
# 9             34              496.677
# 10             9              491.945
# 11            15              485.066
# 12            29              484.310
# 13            35              467.623
# 14            30              467.407
# 15             4              464.917
# 16             2              428.610
# 17            36              412.971
# 18            50              409.631
# 19            25              393.180
#
#                                                 Topic  \
# 0   [(public, 0.168381768411), (safety, 0.13998228...
# 1   [(transportation, 0.164542015423), (traffic, 0...
# 2   [(public, 0.0713314310777), (safety, 0.0690276...
# 3   [(development, 0.176027756751), (housing, 0.15...
# 4   [(financial, 0.0959611006916), (permits, 0.066...
# 5   [(finance, 0.164742098166), (year, 0.062366577...
# 6   [(politics, 0.110698260148), (government, 0.09...
# 7   [(business, 0.0803271304597), (license, 0.0323...
# 8   [(service, 0.0872627144419), (requests, 0.0350...
# 9   [(education, 0.181504757587), (school, 0.08185...
# 10  [(recreation, 0.131286229681), (parks, 0.06452...
# 11  [(budget, 0.141547682714), (finance, 0.0616298...
# 12  [(planning, 0.0609328856062), (county, 0.05924...
# 13  [(infrastructure, 0.0824452424325), (city, 0.0...
# 14  [(mateo, 0.0418424874983), (city, 0.0239850798...
# 15  [(information, 0.0456295107206), (tab, 0.02519...
# 16  [(population, 0.131515203217), (county, 0.0919...
# 17  [(census, 0.0788049808377), (indicators, 0.077...
# 18  [(program, 0.032511463571), (employees, 0.0289...
# 19  [(tax, 0.116949417443), (revenue, 0.0582816749...
#
#                                topic1                         topic2  \
# 0            (public, 0.168381768411)       (safety, 0.139982283853)
# 1    (transportation, 0.164542015423)     (traffic, 0.0382494150922)
# 2           (public, 0.0713314310777)      (safety, 0.0690276616473)
# 3       (development, 0.176027756751)      (housing, 0.152212657649)
# 4        (financial, 0.0959611006916)     (permits, 0.0668632739602)
# 5           (finance, 0.164742098166)         (year, 0.062366577351)
# 6          (politics, 0.110698260148)  (government, 0.0983150505736)
# 7         (business, 0.0803271304597)      (license, 0.032302648157)
# 8          (service, 0.0872627144419)    (requests, 0.0350316945429)
# 9         (education, 0.181504757587)      (school, 0.0818576925692)
# 10       (recreation, 0.131286229681)       (parks, 0.0645285967363)
# 11           (budget, 0.141547682714)     (finance, 0.0616298478188)
# 12        (planning, 0.0609328856062)      (county, 0.0592460462606)
# 13  (infrastructure, 0.0824452424325)        (city, 0.0658933761572)
# 14           (mateo, 0.0418424874983)        (city, 0.0239850798125)
# 15     (information, 0.0456295107206)         (tab, 0.0251926721763)
# 16       (population, 0.131515203217)      (county, 0.0919604340497)
# 17          (census, 0.0788049808377)  (indicators, 0.0773738300794)
# 18          (program, 0.032511463571)   (employees, 0.0289751722757)
# 19              (tax, 0.116949417443)     (revenue, 0.0582816749296)
#
#                              topic3                          topic4  \
# 0          (crime, 0.0631808672948)         (police, 0.03597164994)
# 1         (street, 0.0297088546702)      (parking, 0.0260484479646)
# 2           (fire, 0.0477503790148)        (month, 0.0205819878206)
# 3       (economic, 0.0588541094432)    (community, 0.0485919430535)
# 4       (building, 0.0631953900546)        (permit, 0.054456521697)
# 5          (state, 0.0533822539548)      (monthly, 0.0506962481995)
# 6       (election, 0.0382597777507)     (campaign, 0.0309485620342)
# 7            (job, 0.0220026249885)    (contracts, 0.0219341654552)
# 8     (inspection, 0.0326789351929)  (inspections, 0.0313503518264)
# 9        (schools, 0.0317766682176)     (students, 0.0295716293995)
# 10        (jersey, 0.0605939846627)         (park, 0.0400138091412)
# 11          (fund, 0.0528667079259)         (year, 0.0273615283825)
# 12      (district, 0.0590822346049)    (districts, 0.0460914886485)
# 13        (public, 0.0328457699722)         (maps, 0.0305195329364)
# 14           (gis, 0.0198053782604)         (land, 0.0192192818496)
# 15      (projects, 0.0242891655476)   (concerning, 0.0182745676272)
# 16  (demographics, 0.0842750050866)          (age, 0.0434468663432)
# 17        (survey, 0.0480351597869)     (includes, 0.0448351738525)
# 18         (adult, 0.0244085054991)     (employee, 0.0242968020528)
# 19         (sales, 0.0386343839808)        (taxes, 0.0347130105104)
#
#                                topic5                            topic6  \
# 0       (department, 0.0193424493246)       (illinois, 0.0152118075546)
# 1    (infrastructure, 0.024499661836)           (city, 0.0242484880067)
# 2            (calls, 0.0173756495075)         (police, 0.0170781244666)
# 3   (infrastructure, 0.0190401252932)        (managed, 0.0183046960354)
# 4     (expenditures, 0.0429247389481)          (guide, 0.0250580534259)
# 5           (fiscal, 0.0476222221357)       (payments, 0.0357199197181)
# 6        (elections, 0.0296823051034)     (commission, 0.0293149928715)
# 7       (businesses, 0.0197708503312)         (vendor, 0.0178329754117)
# 8              (311, 0.0263119431044)          (public, 0.025968462717)
# 9           (public, 0.0171734235818)     (governance, 0.0167833173256)
# 10           (center, 0.029877716132)  (neighborhoods, 0.0258798720295)
# 11       (operating, 0.0267145486731)           (city, 0.0261515403541)
# 12      (boundaries, 0.0372114905902)            (city, 0.029524721059)
# 13           (works, 0.0279350117897)         (dallas, 0.0224431406282)
# 14          (county, 0.0188704602627)         (parcel, 0.0173183551841)
# 15             (may, 0.0177403684305)       (contains, 0.0171133718182)
# 16           (total, 0.0282215586982)           (king, 0.0194688109256)
# 17       (indicator, 0.0369245239412)      (community, 0.0332211165998)
# 18          (annual, 0.0204986126128)          (names, 0.0182179413533)
# 19           (local, 0.0332054161494)       (colorado, 0.0306870467969)
#
#                              topic7                           topic8  \
# 0           (race, 0.0133652012852)       (reported, 0.011776909211)
# 1           (safe, 0.0239084069945)       (vehicle, 0.0231351100665)
# 2      (emergency, 0.0165221049163)      (response, 0.0157891037516)
# 3       (medicaid, 0.0178764063515)    (department, 0.0140238290886)
# 4         (issued, 0.0232434329642)  (construction, 0.0228846174877)
# 5     (government, 0.0264540232587)          (june, 0.0225770287471)
# 6        (results, 0.0249283166716)          (city, 0.0213278569983)
# 7          (owned, 0.0175281633585)      (contract, 0.0175169967387)
# 8     (violations, 0.0237687923195)        (request, 0.022587674832)
# 9          (state, 0.0165785793709)          (year, 0.0161596047936)
# 10       (centers, 0.0221407272983)    (facilities, 0.0197678830443)
# 11        (fiscal, 0.0235877561714)         (funds, 0.0201535441911)
# 12         (areas, 0.0270950065527)        (zoning, 0.0266346423368)
# 13           (los, 0.0198827044081)       (angeles, 0.0191921754348)
# 14           (map, 0.0172935426724)         (point, 0.0172170884678)
# 15       (project, 0.0158542813828)      (provided, 0.0138395187013)
# 16    (washington, 0.0192761369915)    (montgomery, 0.0182610800118)
# 17  (demographics, 0.0282093059688)        (bureau, 0.0238720417508)
# 18          (full, 0.0179091183965)         (abuse, 0.0162096834129)
# 19    (government, 0.0297069172677)         (state, 0.0219961180005)
#
#                             topic9                         topic10
# 0        (crimes, 0.0115504690759)     (criminal, 0.0105105785255)
# 1       (streets, 0.0219852292388)         (bike, 0.0155102577616)
# 2     (discharge, 0.0150688301524)     (incident, 0.0140341527688)
# 3     (buildings, 0.0137754059922)      (economy, 0.0123473943134)
# 4   (information, 0.0227968624179)        (filter, 0.021954851646)
# 5          (july, 0.0216759115561)       (report, 0.0215900104843)
# 6           (460, 0.0200805489271)      (finance, 0.0197352160164)
# 7      (licenses, 0.0169698891758)    (certified, 0.0166884614561)
# 8    (complaints, 0.0193704153109)         (days, 0.0180026003213)
# 9       (student, 0.0161397342546)     (district, 0.0160036278832)
# 10  (environment, 0.0172267599485)       (access, 0.0157062019872)
# 11     (calendar, 0.0182912645876)  (communities, 0.0168132558204)
# 12          (gis, 0.0244396763289)      (council, 0.0230826924938)
# 13        (types, 0.0151131207127)          (way, 0.0138871508278)
# 14       (survey, 0.0164839101622)      (feature, 0.0160484881569)
# 15   (additional, 0.0136923822487)  (improvement, 0.0124520027276)
# 16       (number, 0.0179005714425)        (years, 0.0169604724905)
# 17            (u, 0.0211392894776)        (level, 0.0192043130616)
# 18    (nutrition, 0.0157677124596)    (beginning, 0.0142137708217)
# 19   (department, 0.0191541789639)         (sale, 0.0152112241357)

# %%
#a little cleaner view for display online:
def display_view(df):
    
    pd.options.display.max_colwidth = 120 #so we can see our whole topic
    
    clean_topics = []
    for topic_tup in df.Topic: 
        raw_words = list(i[0] for i in topic_tup)
        string = ", ".join(raw_words)
        clean_topics.append(string)
    
    clean_df = df.iloc[:, 0:2] #take off the old topic cols
    clean_df['Topic'] = clean_topics #plug in clean topic strings list to new df
    
    clean_df.columns = ['Topic ID', 'Adjusted Popularity Score', 'Topic Content'] #rename for web
    
    clean_df.index = np.arange(1, len(clean_df.index) + 1) #we'll start index at 1 so it's easier to view ranks
    
    return clean_df

# %%
display_view = display_view(norm_by_areas_df)
display_view
# Out:
#     Topic ID  Adjusted Popularity Score  \
# 1         26                    799.492
# 2          3                    692.631
# 3         21                    670.051
# 4         49                    623.113
# 5         37                    584.586
# 6         40                    582.037
# 7         31                    572.482
# 8         48                    560.589
# 9         41                    499.286
# 10        34                    496.677
# 11         9                    491.945
# 12        15                    485.066
# 13        29                    484.310
# 14        35                    467.623
# 15        30                    467.407
# 16         4                    464.917
# 17         2                    428.610
# 18        36                    412.971
# 19        50                    409.631
# 20        25                    393.180
# 21        27                    387.617
# 22        42                    357.764
# 23        28                    356.698
# 24        11                    346.489
# 25        13                    346.136
# 26        23                    345.531
# 27        39                    341.116
# 28         6                    337.260
# 29        17                    321.496
# 30         1                    320.423
# 31        16                    310.315
# 32         5                    274.758
# 33        12                    266.153
# 34        47                    256.439
# 35        43                    248.788
# 36         0                    247.484
# 37        45                    242.566
# 38        33                    226.347
# 39        24                    224.813
# 40         8                    223.512
# 41        44                    218.401
# 42        22                    218.129
# 43        18                    217.918
# 44        38                    216.225
# 45         7                    214.701
# 46        32                    197.366
# 47        46                    195.113
# 48        10                    185.467
# 49        14                    171.853
# 50        51                    171.328
# 51        19                    170.426
# 52        20                    108.422
#
#                                                                                                    Topic Content
# 1                          public, safety, crime, police, department, illinois, race, reported, crimes, criminal
# 2                   transportation, traffic, street, parking, infrastructure, city, safe, vehicle, streets, bike
# 3                           public, safety, fire, month, calls, police, emergency, response, discharge, incident
# 4   development, housing, economic, community, infrastructure, managed, medicaid, department, buildings, economy
# 5           financial, permits, building, permit, expenditures, guide, issued, construction, information, filter
# 6                                finance, year, state, monthly, fiscal, payments, government, june, july, report
# 7                   politics, government, election, campaign, elections, commission, results, city, 460, finance
# 8                    business, license, job, contracts, businesses, vendor, owned, contract, licenses, certified
# 9                 service, requests, inspection, inspections, 311, public, violations, request, complaints, days
# 10                      education, school, schools, students, public, governance, state, year, student, district
# 11              recreation, parks, jersey, park, center, neighborhoods, centers, facilities, environment, access
# 12                            budget, finance, fund, year, operating, city, fiscal, funds, calendar, communities
# 13                          planning, county, district, districts, boundaries, city, areas, zoning, gis, council
# 14                                   infrastructure, city, public, maps, works, dallas, los, angeles, types, way
# 15                                           mateo, city, gis, land, county, parcel, map, point, survey, feature
# 16             information, tab, projects, concerning, may, contains, project, provided, additional, improvement
# 17                     population, county, demographics, age, total, king, washington, montgomery, number, years
# 18                    census, indicators, survey, includes, indicator, community, demographics, bureau, u, level
# 19                         program, employees, adult, employee, annual, names, full, abuse, nutrition, beginning
# 20                              tax, revenue, sales, taxes, local, colorado, government, state, department, sale
# 21                    water, environment, protection, tx, filed, waste, site, quality, environmental, monitoring
# 22                                  information, list, code, required, political, utah, public, city, years, see
# 23                         transportation, plans, iowa, area, transit, operations, region, bus, priority, people
# 24                  energy, environment, electricity, air, sustainable, action, climate, city, clean, facilities
# 25                       gas, natural, food, greenhouse, environment, emissions, costs, resources, program, fuel
# 26                               police, user, information, page, department, use, orleans, injury, may, records
# 27                             health, san, county, care, counties, system, facilities, network, home, francisco
# 28                 property, consumption, real, value, properties, significant, easy, usage, assessment, company
# 29                            services, social, human, dfps, information, programs, us, definition, visit, state
# 30                                chart, children, income, historic, home, assistance, homes, families, low, pay
# 31           economy, employment, labor, unemployment, insurance, credit, workforce, economic, training, federal
# 32                          locations, bacteria, hours, culture, county, levels, contact, directory, e, contains
# 33                          map, "about", shows, details, tracking, click, view, additional, weekly, information
# 34                                         care, finance, provider, child, cost, plan, day, bay, government, fee
# 35                             state, new, michigan, york, information, check, measurements, jobs, licensing, ny
# 36     prevention, hospital, ny, healthy, statewide, hospitals, inpatient, healthcare, api, quality-safety-costs
# 37                 report, performance, city, goal, resultsnola, administration, city's, management, key, topeka
# 38                         finance, summary, dashboard, ethics, form, management, board, pension, includes, last
# 39           official, account, accounts, (openmichigan@michigan, special, nursing, software, gis, use, consumer
# 40                                            health, disease, 000, per, rate, rates, chronic, risk, agency, due
# 41                           book, lead, stations, databook, station, closed, ecology, solar, power, residential
# 42                               arts, grants, live, county, includes, library, clearance, grant, inventory, cps
# 43                    column, update, homeless, annually, frequency, position, city, commercial, daily, salaries
# 44                   plan, strategic, master, community, fewer, limitations, registry, cause, years, information
# 45                           rates, calculated, rate, year, counts, average, seattle, percent, mortality, number
# 46                            open, created, items, clear, volume, please, presented, difficult, potential, note
# 47                               address, name, number, facility, patient, location, contains, type, g, transfer
# 48            measures, quality, performance, government, life, developed, fair, measurement, definitions, index
# 49                                  health, code, statistics, county, codes, zip, public, diego, harbison, crest
# 50                                      cook, high, cases, youth, case, court, enrollment, college, wa, gis/maps
# 51                           death, maryland, database, deaths, office, department, new, cdc, metadata, citizens
# 52                         expected, dept, observed, every, 300, pacific, physical, performed, contribution, std

# %%
#display_view.to_csv('final_topic_ranks.csv')

# %% [markdown]
# ### Dampened Popularity Results:
# Interesting! Our top transportation tag has fallen out of the Top 10. Perhaps California and Texas really were giving it too much of a boost, even with log_views.
# - We can see that two public safety tags -- I'd call them "reported crimes" "public safety calls" have taken the top spot.
# - Our "Personal Transportation" topic is #2. The real life topic of transportation information is still a popular topic.
# - Interestingly, "annual budget and fiscal year data" comes in at #6 for the first time.
# - 311 calls has fallen all the way to #9! **Unsurprisingly, 311 was a top topic in New York City.**
# - Our parochial datasets have fallen out of the top ranks. This is good.
# - **The separation between popularity metrics is much smaller and less significant. We should take care in making sweeping conclusions.** Again, we set a 0.2 threshold for this scoring category in winner-take_all. Different scoring could change this.

# %% [markdown]
# ### Finally, let's determine most popular topics by domain using *raw totals of dataset views and downloads*.
# - Previously, we looked at the top topics for each domain using log-adjusted scoring.
# - But there's really no need to control for big cities by using a logarithm on our totals when we are comparing WITHIN one city.

# %%
#first let's modify our old proportional_popularity function to just count TOTAL views and downloads; 
#no need to take the log to control for big cities if we are ONLY calculating what's most popular in one city

def calc_raw_pop(df):
    df = df.fillna(0)
    results_dict = {}
    
    for row_num in df.index:
        for tup in df.topic_comp[row_num]: #no need to pick a winner here...
            if not tup[0] in results_dict:
                if tup[1] >= 0.2: #.loc interprets as the label of the index, not int position
                    results_dict[tup[0]] = (tup[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total))
                else:
                    pass
            if tup[0] in results_dict:
                if tup[1] >= 0.2:
                    results_dict[tup[0]] += (tup[1] * (df.loc[row_num].download_count + 
                                             df.loc[row_num].page_views_total))
    return results_dict

# %%
#next we need to modify our specific domain popularity function to call calc_raw_pop, not calc_proportional_pop
def raw_popularity_by_domain(df, domain_name):
    
    domain_df = df[df.domain == domain_name]
    popularity_dict = calc_raw_pop(domain_df) #we're still using our proportional scoring here
    
    df_pop = pd.DataFrame.from_dict(popularity_dict, orient='index') #dict is in df but index numbers (aka topic numbers) are random
    df_pop = df_pop.rename(index=int, columns={0:"Adjusted_Popularity"})
    
    topic_words_list = []
    for topic_num in df_pop.index: #this iterates in the right order - index numbers have real meaning
        topic_tups = lda_52_sixty.show_topic(topic_num)
        raw_words = list(i[0] for i in lda_52_sixty.show_topic(topic_num))
        string = ", ".join(raw_words)
        topic_words_list.append(string) #plug in names by index numbers
    
    df_pop['Topic_Words'] = topic_words_list
    
    df_pop = df_pop.sort_values(by='Adjusted_Popularity', ascending=False)
    
    #put the domain in each row - kind of an ugly way to preserve info about domain but it's what we've got
    domain_string = domain_name
    df_pop['Domain'] = [domain_string for number in range(len(df_pop.index))]
    
    return df_pop

# %% [markdown]
# **Finally, we'll modify our top_topics_by_domain() function to use this raw metric of scoring**
# - I really should have restructured how I wrote these and used @decorators. Oh well.

# %%
def raw_top_topics_by_domain(df, domains_series):
    
    domains_dict = {}
    for domain in domains_series:
        
        domain_df = raw_popularity_by_domain(df, domain) #this is a df like the Madison example
        Topic = domain_df.iloc[0].Topic_Words #string
        Domain = domain_df.iloc[0].Domain.split() #have to remember to split(), which really just gives us one word
        
        if Topic in domains_dict: 
            domains_dict[Topic] += Domain
        else:
            domains_dict[Topic] = list(Domain)
    
    return domains_dict

# %%
raw_most_popular = raw_top_topics_by_domain(topics, topics.domain.unique()) 
#again, should have just put this second arg in the functio

# %%
raw_most_popular
# Out:
# {'budget, finance, fund, year, operating, city, fiscal, funds, calendar, communities': ['data.macoupincountyil.gov',
#   'data.tompsc.com',
#   'data.topeka.org',
#   'information.stpaul.gov',
#   'performance.danvilleva.gov',
#   'performance.franklintn.gov'],
#  'business, license, job, contracts, businesses, vendor, owned, contract, licenses, certified': ['data.cityofgainesville.org',
#   'data.culvercity.org',
#   'data.oxnard.org',
#   'opendata.cityofhenderson.com'],
#  'care, finance, provider, child, cost, plan, day, bay, government, fee': ['data.datamontana.us'],
#  'census, indicators, survey, includes, indicator, community, demographics, bureau, u, level': ['data.livewellsd.org',
#   'opendata.cityofmesquite.com'],
#  'development, housing, economic, community, infrastructure, managed, medicaid, department, buildings, economy': ['dashboard.alexandriava.gov',
#   'data.countyofriverside.us',
#   'data.hampton.gov',
#   'data.maine.gov',
#   'stat.cityofgainesville.org'],
#  'economy, employment, labor, unemployment, insurance, credit, workforce, economic, training, federal': ['data.iowa.gov'],
#  'education, school, schools, students, public, governance, state, year, student, district': ['dashboard.hawaii.gov',
#   'data.mass.gov',
#   'data.vermont.gov'],
#  'energy, environment, electricity, air, sustainable, action, climate, city, clean, facilities': ['data.results.wa.gov',
#   'data.sustainablesm.org',
#   'performance.providenceri.gov'],
#  'finance, year, state, monthly, fiscal, payments, government, june, july, report': ['data.maryland.gov',
#   'data.nj.gov',
#   'impact.stlouisco.com',
#   'opencheckbook.data.somervillema.gov',
#   'opendata.lasvegasnevada.gov',
#   'performance.cookcountyil.gov',
#   'transparency.michigan.gov'],
#  'financial, permits, building, permit, expenditures, guide, issued, construction, information, filter': ['data.burlingtonvt.gov',
#   'data.cityofboston.gov',
#   'data.cityofevanston.org',
#   'data.cstx.gov',
#   'data.fortworthtexas.gov',
#   'data.lacity.org',
#   'data.montgomeryal.gov',
#   'data.nashville.gov',
#   'data.tuscaloosa.com'],
#  'gas, natural, food, greenhouse, environment, emissions, costs, resources, program, fuel': ['dashboard.slco.org',
#   'opendata.utah.gov'],
#  'health, code, statistics, county, codes, zip, public, diego, harbison, crest': ['data.mo.gov'],
#  'health, disease, 000, per, rate, rates, chronic, risk, agency, due': ['healthdata.nj.gov'],
#  'health, san, county, care, counties, system, facilities, network, home, francisco': ['data.smcgov.org',
#   'health.data.ny.gov'],
#  'information, tab, projects, concerning, may, contains, project, provided, additional, improvement': ['data.austintexas.gov',
#   'data.lcb.wa.gov',
#   'data.pa.gov'],
#  'infrastructure, city, public, maps, works, dallas, los, angeles, types, way': ['data.albanyny.gov',
#   'data.jacksonms.gov',
#   'data.wa.gov',
#   'opencity.fcgov.com'],
#  'map, "about", shows, details, tracking, click, view, additional, weekly, information': ['data.sonomacounty.ca.gov',
#   'data.vta.org'],
#  'mateo, city, gis, land, county, parcel, map, point, survey, feature': ['data.cityofwestsacramento.org',
#   'data.detroitmi.gov'],
#  'measures, quality, performance, government, life, developed, fair, measurement, definitions, index': ['performance.smcgov.org',
#   'performance.topeka.org'],
#  'open, created, items, clear, volume, please, presented, difficult, potential, note': ['data.baltimorecity.gov'],
#  'plan, strategic, master, community, fewer, limitations, registry, cause, years, information': ['data.cincinnati-oh.gov',
#   'data.monroecounty-fl.gov'],
#  'planning, county, district, districts, boundaries, city, areas, zoning, gis, council': ['data.acgov.org',
#   'data.kcmo.org'],
#  'police, user, information, page, department, use, orleans, injury, may, records': ['data.cityofchicago.org',
#   'data.hartford.gov',
#   'data.menlopark.org',
#   'data.nola.gov',
#   'data.urbanaillinois.us'],
#  'politics, government, election, campaign, elections, commission, results, city, 460, finance': ['dashboard.plano.gov',
#   'data.ct.gov',
#   'data.hawaii.gov',
#   'data.kingcounty.gov',
#   'data.ny.gov',
#   'data.redmond.gov',
#   'datapoints.dallascityhall.com',
#   'electionsdata.kingcounty.gov',
#   'performance.adcogov.org',
#   'performance.glendaleca.gov',
#   'performance.seattle.gov',
#   'performance.vbgov.com',
#   'policeview.johnscreekga.gov'],
#  'population, county, demographics, age, total, king, washington, montgomery, number, years': ['data.cityofnewyork.us',
#   'data.illinois.gov',
#   'performance.carson.org',
#   'performance.princegeorgescountymd.gov'],
#  'program, employees, adult, employee, annual, names, full, abuse, nutrition, beginning': ['data.lacounty.gov',
#   'datacatalog.cookcountyil.gov'],
#  'property, consumption, real, value, properties, significant, easy, usage, assessment, company': ['data.douglas.co.us',
#   'data.qac.org',
#   'data.richmondgov.com'],
#  'public, safety, crime, police, department, illinois, race, reported, crimes, criminal': ['data.auburnwa.gov',
#   'data.greensboro-nc.gov',
#   'data.honolulu.gov',
#   'data.littlerock.gov',
#   'data.naperville.il.us',
#   'data.oaklandnet.com',
#   'data.providenceri.gov',
#   'data.readingpa.gov',
#   'data.roseville.ca.us',
#   'data.somervillema.gov',
#   'data.vbgov.com',
#   'opendata.miamidade.gov',
#   'performance.ci.janesville.wi.us',
#   'performance.cityofdavenportiowa.com',
#   'performance.fultoncountyga.gov',
#   'tni.princegeorgescountymd.gov'],
#  'public, safety, fire, month, calls, police, emergency, response, discharge, incident': ['data.brla.gov',
#   'data.cityofmadison.com',
#   'data.marincounty.org',
#   'data.raleighnc.gov',
#   'data.seattle.gov',
#   'kcstat.kcmo.org',
#   'opendata.ci.richmond.ca.us',
#   'opendata.howardcountymd.gov',
#   'performance.cityofrc.us',
#   'stats.cityofcarrollton.com',
#   'www.dallasopendata.com'],
#  'rates, calculated, rate, year, counts, average, seattle, percent, mortality, number': ['outcomestat.baltimorecity.gov'],
#  'recreation, parks, jersey, park, center, neighborhoods, centers, facilities, environment, access': ['data.srcity.org',
#   'performance.williamsburgva.gov'],
#  "report, performance, city, goal, resultsnola, administration, city's, management, key, topeka": ['performance.austintexas.gov'],
#  'service, requests, inspection, inspections, 311, public, violations, request, complaints, days': ['data.delaware.gov',
#   'data.muni.org',
#   'data.princegeorgescountymd.gov'],
#  'state, new, michigan, york, information, check, measurements, jobs, licensing, ny': ['data.michigan.gov',
#   'data.oregon.gov',
#   'midashboard.michigan.gov'],
#  'transportation, plans, iowa, area, transit, operations, region, bus, priority, people': ['data.cityofgp.com',
#   'data.texas.gov'],
#  'transportation, traffic, street, parking, infrastructure, city, safe, vehicle, streets, bike': ['data.cambridgema.gov',
#   'data.cityoftacoma.org',
#   'data.montgomerycountymd.gov',
#   'data.rutlandcitypolice.com',
#   'data.sfgov.org',
#   'data.weho.org',
#   'insights.cincinnati-oh.gov',
#   'performance.chattanooga.gov',
#   'reports.data.montgomerycountymd.gov'],
#  'water, environment, protection, tx, filed, waste, site, quality, environmental, monitoring': ['data.colorado.gov']}

# %%
#turn this into a DataFrame for export
pop_by_portal = pd.DataFrame([raw_most_popular])
pop_by_portal = pop_by_portal.T
pop_by_portal = pop_by_portal.reset_index()
pop_by_portal.columns = ['Topic Content', 'Domains Where Topic Most Popular']

# %%
pd.set_option('display.max_colwidth', 250)
pop_by_portal
# Out:
#                                                                                                    Topic Content  \
# 0                             budget, finance, fund, year, operating, city, fiscal, funds, calendar, communities
# 1                    business, license, job, contracts, businesses, vendor, owned, contract, licenses, certified
# 2                                          care, finance, provider, child, cost, plan, day, bay, government, fee
# 3                     census, indicators, survey, includes, indicator, community, demographics, bureau, u, level
# 4   development, housing, economic, community, infrastructure, managed, medicaid, department, buildings, economy
# 5            economy, employment, labor, unemployment, insurance, credit, workforce, economic, training, federal
# 6                       education, school, schools, students, public, governance, state, year, student, district
# 7                   energy, environment, electricity, air, sustainable, action, climate, city, clean, facilities
# 8                                finance, year, state, monthly, fiscal, payments, government, june, july, report
# 9           financial, permits, building, permit, expenditures, guide, issued, construction, information, filter
# 10                       gas, natural, food, greenhouse, environment, emissions, costs, resources, program, fuel
# 11                                  health, code, statistics, county, codes, zip, public, diego, harbison, crest
# 12                                            health, disease, 000, per, rate, rates, chronic, risk, agency, due
# 13                             health, san, county, care, counties, system, facilities, network, home, francisco
# 14             information, tab, projects, concerning, may, contains, project, provided, additional, improvement
# 15                                   infrastructure, city, public, maps, works, dallas, los, angeles, types, way
# 16                          map, "about", shows, details, tracking, click, view, additional, weekly, information
# 17                                           mateo, city, gis, land, county, parcel, map, point, survey, feature
# 18            measures, quality, performance, government, life, developed, fair, measurement, definitions, index
# 19                            open, created, items, clear, volume, please, presented, difficult, potential, note
# 20                   plan, strategic, master, community, fewer, limitations, registry, cause, years, information
# 21                          planning, county, district, districts, boundaries, city, areas, zoning, gis, council
# 22                               police, user, information, page, department, use, orleans, injury, may, records
# 23                  politics, government, election, campaign, elections, commission, results, city, 460, finance
# 24                     population, county, demographics, age, total, king, washington, montgomery, number, years
# 25                         program, employees, adult, employee, annual, names, full, abuse, nutrition, beginning
# 26                 property, consumption, real, value, properties, significant, easy, usage, assessment, company
# 27                         public, safety, crime, police, department, illinois, race, reported, crimes, criminal
# 28                          public, safety, fire, month, calls, police, emergency, response, discharge, incident
# 29                           rates, calculated, rate, year, counts, average, seattle, percent, mortality, number
# 30              recreation, parks, jersey, park, center, neighborhoods, centers, facilities, environment, access
# 31                 report, performance, city, goal, resultsnola, administration, city's, management, key, topeka
# 32                service, requests, inspection, inspections, 311, public, violations, request, complaints, days
# 33                             state, new, michigan, york, information, check, measurements, jobs, licensing, ny
# 34                         transportation, plans, iowa, area, transit, operations, region, bus, priority, people
# 35                  transportation, traffic, street, parking, infrastructure, city, safe, vehicle, streets, bike
# 36                    water, environment, protection, tx, filed, waste, site, quality, environmental, monitoring
#
#                                                                                                                                                                                                                              Domains Where Topic Most Popular
# 0                                                                                                               [data.macoupincountyil.gov, data.tompsc.com, data.topeka.org, information.stpaul.gov, performance.danvilleva.gov, performance.franklintn.gov]
# 1                                                                                                                                                            [data.cityofgainesville.org, data.culvercity.org, data.oxnard.org, opendata.cityofhenderson.com]
# 2                                                                                                                                                                                                                                       [data.datamontana.us]
# 3                                                                                                                                                                                                          [data.livewellsd.org, opendata.cityofmesquite.com]
# 4                                                                                                                                       [dashboard.alexandriava.gov, data.countyofriverside.us, data.hampton.gov, data.maine.gov, stat.cityofgainesville.org]
# 5                                                                                                                                                                                                                                             [data.iowa.gov]
# 6                                                                                                                                                                                                     [dashboard.hawaii.gov, data.mass.gov, data.vermont.gov]
# 7                                                                                                                                                                                 [data.results.wa.gov, data.sustainablesm.org, performance.providenceri.gov]
# 8                                                                           [data.maryland.gov, data.nj.gov, impact.stlouisco.com, opencheckbook.data.somervillema.gov, opendata.lasvegasnevada.gov, performance.cookcountyil.gov, transparency.michigan.gov]
# 9                                                            [data.burlingtonvt.gov, data.cityofboston.gov, data.cityofevanston.org, data.cstx.gov, data.fortworthtexas.gov, data.lacity.org, data.montgomeryal.gov, data.nashville.gov, data.tuscaloosa.com]
# 10                                                                                                                                                                                                                    [dashboard.slco.org, opendata.utah.gov]
# 11                                                                                                                                                                                                                                              [data.mo.gov]
# 12                                                                                                                                                                                                                                        [healthdata.nj.gov]
# 13                                                                                                                                                                                                                      [data.smcgov.org, health.data.ny.gov]
# 14                                                                                                                                                                                                       [data.austintexas.gov, data.lcb.wa.gov, data.pa.gov]
# 15                                                                                                                                                                                   [data.albanyny.gov, data.jacksonms.gov, data.wa.gov, opencity.fcgov.com]
# 16                                                                                                                                                                                                                   [data.sonomacounty.ca.gov, data.vta.org]
# 17                                                                                                                                                                                                        [data.cityofwestsacramento.org, data.detroitmi.gov]
# 18                                                                                                                                                                                                           [performance.smcgov.org, performance.topeka.org]
# 19                                                                                                                                                                                                                                   [data.baltimorecity.gov]
# 20                                                                                                                                                                                                         [data.cincinnati-oh.gov, data.monroecounty-fl.gov]
# 21                                                                                                                                                                                                                            [data.acgov.org, data.kcmo.org]
# 22                                                                                                                                                     [data.cityofchicago.org, data.hartford.gov, data.menlopark.org, data.nola.gov, data.urbanaillinois.us]
# 23  [dashboard.plano.gov, data.ct.gov, data.hawaii.gov, data.kingcounty.gov, data.ny.gov, data.redmond.gov, datapoints.dallascityhall.com, electionsdata.kingcounty.gov, performance.adcogov.org, performance.glendaleca.gov, performance.seattle.gov, per...
# 24                                                                                                                                                  [data.cityofnewyork.us, data.illinois.gov, performance.carson.org, performance.princegeorgescountymd.gov]
# 25                                                                                                                                                                                                          [data.lacounty.gov, datacatalog.cookcountyil.gov]
# 26                                                                                                                                                                                                   [data.douglas.co.us, data.qac.org, data.richmondgov.com]
# 27  [data.auburnwa.gov, data.greensboro-nc.gov, data.honolulu.gov, data.littlerock.gov, data.naperville.il.us, data.oaklandnet.com, data.providenceri.gov, data.readingpa.gov, data.roseville.ca.us, data.somervillema.gov, data.vbgov.com, opendata.miami...
# 28  [data.brla.gov, data.cityofmadison.com, data.marincounty.org, data.raleighnc.gov, data.seattle.gov, kcstat.kcmo.org, opendata.ci.richmond.ca.us, opendata.howardcountymd.gov, performance.cityofrc.us, stats.cityofcarrollton.com, www.dallasopendata....
# 29                                                                                                                                                                                                                            [outcomestat.baltimorecity.gov]
# 30                                                                                                                                                                                                          [data.srcity.org, performance.williamsburgva.gov]
# 31                                                                                                                                                                                                                              [performance.austintexas.gov]
# 32                                                                                                                                                                                         [data.delaware.gov, data.muni.org, data.princegeorgescountymd.gov]
# 33                                                                                                                                                                                             [data.michigan.gov, data.oregon.gov, midashboard.michigan.gov]
# 34                                                                                                                                                                                                                        [data.cityofgp.com, data.texas.gov]
# 35                        [data.cambridgema.gov, data.cityoftacoma.org, data.montgomerycountymd.gov, data.rutlandcitypolice.com, data.sfgov.org, data.weho.org, insights.cincinnati-oh.gov, performance.chattanooga.gov, reports.data.montgomerycountymd.gov]
# 36                                                                                                                                                                                                                                        [data.colorado.gov]

# %% [markdown]
# **This can provide some interesting insights, but beware of using it for portals that have only a handful of open datasets. Using the raw total views and downloads can be misleading!**

# %%
#pop_by_portal.to_csv('most_popular_topics_by_portal_by_raw_totals.csv') #export

# %% [markdown]
# ## A function to return rows with a given topic number present:
# - We can use this to view datasets where a given topic wins.

# %%
def return_data_by_top_topic(df, topic_num):
    index_list = []
    for index, tup_list in enumerate(df.topic_comp):
        if (any(topic_num in tup for tup in tup_list)): #if a topic num is in topic_comp
            win_tuple = max(tup_list, key=lambda item:item[1]) #call winning tuple
            if win_tuple[0] == topic_num: #if winning tuple is the topic we want
                index_list.append(index) #append index number to list
    
    df = df.iloc[index_list] #then just select with this list
    return df

# %%
pd.reset_option('display.max_colwidth') #reset our display to default

# %%
twenty_six = return_data_by_top_topic(topics, 26)
twenty_six[0:200]
# Out:
#       Unnamed: 0                                               name  \
# 21            21                     DCHS_Safety_DVSA Hotline Calls
# 22            22                      Exit Plan for Leaving Shelter
# 88            88  Total People Reached Through Community Engagem...
# 101          101                          Length of Stay at Shelter
# 160          160  Adults and Children Sheltered due to Domestic ...
# 161          161             DCHS_SA_Domestic Violence Shelter Data
# 231          231             DCHS_Safety_DVSA Hotline Calls by Type
# 239          239  DCHS_SA_Domestic Violence And Sexual Assault C...
# 252          252  Percent of Participants who Report that they L...
# 272          272             OHA Baseline Target - Viable Land Base
# 275          275             OHA Baseline - Value History & Culture
# 286          286       Hawai'i Homeless Counts by Island, 2010-2013
# 316          316  State of Hawaiʻi Population by Race/Ethnicity:...
# 340          340              Decibel Level of Civil Defense Sirens
# 358          358                 TANF Caseload (By Selected Months)
# 394          394                             Health - Obesity (OHA)
# 431          431             OHA Baseline Target - Viable Land Base
# 437          437                          Public Safety Budget Data
# 444          444                        Map Of Civil Defense Sirens
# 459          459                 WIC Clinic Participation 2010-2013
# 503          503       Hawai'i Homeless Counts by Island, 2010-2013
# 517          517                             Women's Health Clinics
# 523          523                            Health - Prenatal (OHA)
# 534          534  State of Hawaiʻi Population by Race/Ethnicity:...
# 568          568                              Fire / EMS Dispatches
# 575          575                                     EMS Dispatches
# 583          583                                     EMS Dispatches
# 614          614                                   Index Crime Rate
# 632          632                             State Index Crime Rate
# 655          655               Alameda County Sheriff Crime Reports
# ...          ...                                                ...
# 4262        4262  Uniform Crime Reporting System Offenses by Dep...
# 4286        4286     Uniform Crime Reporting System Arrests in 2012
# 4287        4287                                 Police Departments
# 4290        4290       Uniform Crime Reporting System Offenses 2011
# 4292        4292  Uniform Crime Reporting System Offenses By Dep...
# 4294        4294    Uniform Crime Reporting System Arrests in  2010
# 4302        4302  Number of Law Enforcement Personnel by Departm...
# 4329        4329    Uniform Crime Reporting System Offenses in 2010
# 4362        4362        CHART : LICENSE ENDORSEMENTS as of NOV 2013
# 4388        4388        CHART : LICENSE ENDORSEMENTS as of NOV 2014
# 4399        4399  Uniform Crime Reporting System Offenses By Dep...
# 4407        4407       Uniform Crime Reporting System Offenses 2012
# 4431        4431                  City of New Haven Police Stations
# 4439        4439           Vehicle Crash Data Repository - CT CRASH
# 4451        4451        CHART : LICENSE ENDORSEMENTS as of NOV 2012
# 4478        4478  Commercial Vehicle Safety Division- Consumer C...
# 4524        4524        Uniform Crime Reporting System Arrests 2015
# 4528        4528  Uniform Crime Reporting System Offenses By Dep...
# 4529        4529              Public Safety Answering Points (PSAP)
# 4539        4539                                     PSAP Districts
# 4812        4812              DPD: Reported Major Crimes, 2011-2014
# 4828        4828  DPD: 2015 Homicide Offenses - Victims (Confirmed)
# 4839        4839                                      DPD Precincts
# 4859        4859  DPD: 2015 Non-Fatal Shooting Offenses - Victim...
# 4867        4867  DPD: 2015 Carjacking Offenses - Victims (Confi...
# 4871        4871  DPD: 2014 Homicide Offenses - Victims (Confirmed)
# 4873        4873  DPD: 2015 Homicide Offenses - Victims (Confirm...
# 4875        4875  DPD: 2014 Non-Fatal Shooting Offenses - Victim...
# 4880        4880  DPD: 2015 Carjacking Offenses - Victims (Confi...
# 4889        4889  DPD: 2015 Non-Fatal Shooting Offenses - Victim...
#
#                                             description  \
# 21                                                   []
# 22                                                   []
# 88                                                   []
# 101                                                  []
# 160                                                  []
# 161                                                  []
# 231                                                  []
# 239                                                  []
# 252                                                  []
# 272   ['OHA', 'Strategic', 'Results', '(2010', '2018...
# 275   ['85%', 'of', 'Hawaiʻi', 'residents', 'appreci...
# 286                                                  []
# 316                                                  []
# 340   ['Includes', 'decibel', 'levels', 'and', 'prec...
# 358                                                  []
# 394                                                  []
# 431   ['OHA', 'Strategic', 'Results', '(2010', '2018...
# 437                                                  []
# 444   ['Includes', 'decibel', 'levels', 'and', 'prec...
# 459                                                  []
# 503                                                  []
# 517                                                  []
# 523                                                  []
# 534                                                  []
# 568                                                  []
# 575                                                  []
# 583                                                  []
# 614   ['Salt', 'Lake', 'County', 'crime', 'rates', '...
# 632   ['State', 'of', 'Utah', 'crime', 'rates', 'sta...
# 655   ['Alameda', 'County', 'Sheriff', 'Crime', 'Rep...
# ...                                                 ...
# 4262  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4286  ['Arrests', 'are', 'the', 'number', 'of', 'per...
# 4287  ['A', 'listing', 'of', 'State', 'Municipal', '...
# 4290  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4292  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4294  ['Arrests', 'are', 'the', 'number', 'of', 'per...
# 4302  ['The', 'number', 'of', 'sworn', 'and', 'civil...
# 4329  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4362                                                 []
# 4388                                                 []
# 4399  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4407  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4431  ['Locations', 'of', 'Police', 'Stations', 'in'...
# 4439  ['The', 'Connecticut', 'Crash', 'Data', 'Repos...
# 4451                                                 []
# 4478  ['CVSD', 'Consumer', 'Complaint', 'Cases', 'be...
# 4524  ['Arrests', 'are', 'the', 'number', 'of', 'per...
# 4528  ['The', 'Uniform', 'Crime', 'Reporting', 'Prog...
# 4529  ['Connecticut', 'Public', 'Safety', 'Answering...
# 4539  ['Connecticut', 'Public', 'Safety', 'Answering...
# 4812  ['Reported', 'major', 'crime', 'offenses', 'fr...
# 4828  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4839  ['Detroit', 'Police', 'Department', 'precinct'...
# 4859  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4867  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4871  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4873  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4875  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4880  ['Year', 'end', 'victim', 'based', 'listing', ...
# 4889  ['Year', 'end', 'victim', 'based', 'listing', ...
#
#                                             attribution  \
# 21                                                  NaN
# 22                                                  NaN
# 88                                                  NaN
# 101                                                 NaN
# 160                                                 NaN
# 161                                                 NaN
# 231                                                 NaN
# 239                                                 NaN
# 252                                                 NaN
# 272   Field Note: Baseline Hawai'i State, Office of ...
# 275                                                 OHA
# 286                                  Source: PIT, 2013.
# 316   Source. Hawaiʻi, Department of Health, Hawaiʻi...
# 340                                                 NaN
# 358                                                 NaN
# 394                                                 NaN
# 431   Field Note: Baseline Hawai'i State, Office of ...
# 437                                                 NaN
# 444                                                 NaN
# 459   Kayla Rosenfeld, DHS; WIC services in Hawaii, ...
# 503                                  Source: PIT, 2013.
# 517                                                 NaN
# 523                                                 NaN
# 534   Source. Hawaiʻi, Department of Health, Hawaiʻi...
# 568                                                 NaN
# 575                                                 NaN
# 583                                                 NaN
# 614                    Utah Department of Public Safety
# 632                    Utah Department of Public Safety
# 655                     Alameda County Sheriff's Office
# ...                                                 ...
# 4262  Department of Emergency Services and Public Pr...
# 4286  Department of Emergency Services and Public Pr...
# 4287  Department of Emergency Service and Public Pro...
# 4290  Department of Emergency Services and Public Pr...
# 4292  Department of Emergency Services and Public Pr...
# 4294  Department of Emegerncy Service and Public Pro...
# 4302  Department of Emergency Services and Public Pr...
# 4329  Department of Emergency Services and Public Pr...
# 4362                        DEPARTMENT OF MOTOR VEHICLE
# 4388                        DEPARTMENT OF MOTOR VEHICLE
# 4399  Department of Emergency Services and Public Pr...
# 4407  Department of Emergency Services and Public Pr...
# 4431                                  City of New Haven
# 4439                       Department of Transportation
# 4451                        DEPARTMENT OF MOTOR VEHICLE
# 4478                       Department of Motor Vehicles
# 4524  Department of Emergency Services and Public Pr...
# 4528  Department of Emergency Services and Public Pr...
# 4529                                                NaN
# 4539                                                NaN
# 4812                                                DPD
# 4828                          Detroit Police Department
# 4839                          Detroit Police Department
# 4859                          Detroit Police Department
# 4867                          Detroit Police Department
# 4871                          Detroit Police Department
# 4873                          Detroit Police Department
# 4875                          Detroit Police Department
# 4880                          Detroit Police Department
# 4889                          Detroit Police Department
#
#                                      columns_field_name  \
# 21    ['sexual_assault_hotline_calls', 'other_servic...
# 22    ['sexual_assault_hotline_calls', 'percent_of_c...
# 88    ['percent_of_participants_reported_that_they_l...
# 101   ['unknown', 'left_area', 'residence_of_friend_...
# 160   ['residence_of_friend_relative', 'transitional...
# 161   ['over_90_days', 'length_of_stay_less_than_24_...
# 231   ['children_sheltered_due_to_domestic_violence'...
# 239   ['total_people_reached', 'total_hours_of_activ...
# 252   ['race_of_participants_caucasian', 'race_of_pa...
# 272   ['annual_target_population', 'fiscal_year', 'y...
# 275   ['annual_target_hi_adult_resident', 'oha_targe...
# 286   ['homeless_count', 'county', 'year', 'hawai_i'...
# 316   ['population_percent', 'population_number', 'r...
# 340   ['decibel', 'location', 'unique_id', 'location...
# 358   ['of_employed_households', 'gross_earned_incom...
# 394   ['date', 'hp2020_benchmark', 'oha_benchmark', ...
# 431   ['year', 'annual_target_population', 'fiscal_y...
# 437   ['total_operating', 'fiscal_year', 'total_capi...
# 444   ['location', 'decibel', 'county', 'location_1'...
# 459   ['total_served', 'infants', 'women', 'children...
# 503   ['homeless_count', 'kaua_i', 'year', 'hawai_i'...
# 517                   ['clinic', 'phone', 'location_1']
# 523   ['unknown_n', 'oha_benchmark', 'hp2020_benchma...
# 534   ['population_number', 'race_ethnicity', 'popul...
# 568   ['med_inj_processing', 'fire_ems_disp_avg', 'f...
# 575   ['fire', '_911_via_telematics', 'voip', '_911_...
# 583   ['fire', '_911_via_telematics', '_911_via_voip...
# 614                             ['year2', 'crime_rate']
# 632                        ['date', 'state_crime_rate']
# 655   ['crimedescription', 'location_1', 'datetime',...
# ...                                                 ...
# 4262  ['robbery_gas_service_station_value_stolen', '...
# 4286  ['colchester_csp', 'torrington_pd', 'tolland_c...
# 4287  ['telephone', 'address', 'location', 'zip', 'c...
# 4290  ['milford_pd', 'hamden_pd', 'westbrook_csp', '...
# 4292  ['arson_other_value_damaged', 'smasslt_offense...
# 4294  ['winchester_pd', 'colchester_csp', 'woodbridg...
# 4302  ['department', 'sworn_male', 'civilian_female'...
# 4329  ['enfield_pd', 'csp_total', 'foxwoods_casino_c...
# 4362          ['total', 'license_endosrements', 'year']
# 4388          ['year', 'total', 'license_endosrements']
# 4399  ['ngmansl_clearances', 'murder_relationship_st...
# 4407  ['brooklyn_csp', 'stonington_pd', 'stamford_pd...
# 4431                                                 []
# 4439                                                 []
# 4451          ['year', 'total', 'license_endosrements']
# 4478  ['cases_closed', 'year', 'month', 'cases_open'...
# 4524  ['urban', 'tolland_county', 'w_c_s_u', 's_c_s_...
# 4528  ['murder_relationship_live_in_male', 'murder_r...
# 4529                                                 []
# 4539                                                 []
# 4812  ['category', 'rownum', 'hour', 'location', 'ce...
# 4828  ['y', 'x', 'state', 'day', 'fid', 'report_no',...
# 4839                                                 []
# 4859  ['state', 'day', 'location_1', 'precinct', 'fi...
# 4867  ['y', 'state', 'day', 'location_1', 'time', 'r...
# 4871  ['day', 'date', 'fid', 'precinct', 'report_no'...
# 4873                                                 []
# 4875  ['city', 'fid', 'x', 'state', 'precinct', 'dat...
# 4880                                                 []
# 4889                                                 []
#
#                                            columns_name     type  \
# 21    ['Sexual Assault Hotline Calls', 'Other Servic...    chart
# 22    ['Sexual Assault Hotline Calls', 'Percent of c...    chart
# 88    ['Percent of participants reported that they l...    chart
# 101   ['Unknown', 'Left Area', 'Residence of friend/...    chart
# 160   ['Residence of friend/relative', 'Transitional...    chart
# 161   ['Over 90 days', 'Less than 24 hours', 'Reside...  dataset
# 231   ['Children sheltered due to Domestic Violence'...    chart
# 239   ['Total People Reached', 'Total Hours of Activ...  dataset
# 252   ['Race of Participants - Caucasian', 'Race of ...    chart
# 272   ['Annual Target Population ', 'Fiscal Year', '...    chart
# 275   ['Annual Target (HI adult resident)', 'OHA Tar...    chart
# 286      ['Maui', "O'ahu", 'Year', "Hawai'i", "Kaua'i"]    chart
# 316   ['Population (Percent)', 'Population (Number)'...    chart
# 340   ['DECIBEL', 'LOCATION', 'UNIQUE_ID', 'Location...      map
# 358   ['# of Employed Households', 'Gross Earned Inc...    chart
# 394   ['Date', 'HP2020 Benchmark', 'OHA Benchmark', ...  dataset
# 431   ['Date', 'Annual Target Population ', 'Fiscal ...  dataset
# 437   ['Total Operating', 'Fiscal Year', 'Total Capi...  dataset
# 444   ['LOCATION', 'DECIBEL', 'COUNTY', 'Location 1'...  dataset
# 459   ['Total Served', 'Infants', 'Women', 'Children...  dataset
# 503      ['Maui', "Kaua'i", 'Year', "Hawai'i", "O'ahu"]  dataset
# 517                   ['Clinic', 'Phone', 'Location 1']  dataset
# 523   ['Unknown (N)', 'OHA Benchmark', 'HP2020 Bench...  dataset
# 534   ['Population (Number)', 'Race/Ethnicity ', 'Po...  dataset
# 568   ['PFR Med/Inj Processing 90th', 'Fire / EMS Di...    chart
# 575   ['% Fire', '911 via Telematics', '% VoiP', '91...    chart
# 583   ['% Fire', '911 via Telematics', '911 via VoiP...    chart
# 614                             ['Year2', 'CRIME RATE']  dataset
# 632                        ['DATE', 'STATE CRIME RATE']  dataset
# 655   ['CrimeDescription', 'Location 1', 'DateTime',...  dataset
# ...                                                 ...      ...
# 4262  ['Robbery Gas/Service_Station Value_Stolen', '...  dataset
# 4286  ['Colchester CSP', 'Torrington PD', 'Tolland C...  dataset
# 4287  ['TELEPHONE', 'ADDRESS', 'Location', 'ZIP', 'C...  dataset
# 4290  ['Milford PD', 'Hamden PD', 'Westbrook CSP', '...  dataset
# 4292  ['Arson Other Value_Damaged', 'SmAsslt Offense...  dataset
# 4294  ['Winchester PD', 'Colchester CSP', 'Woodbridg...  dataset
# 4302  ['Department', 'Sworn Male ', 'Civilian Female...  dataset
# 4329  ['Enfield PD', 'CSP Total', 'Foxwoods Casino C...  dataset
# 4362          ['TOTAL', 'LICENSE ENDOSREMENTS', 'YEAR']    chart
# 4388          ['YEAR', 'TOTAL', 'LICENSE ENDOSREMENTS']    chart
# 4399  ['NgMansl Clearances', 'Murder Relationship St...  dataset
# 4407  ['Brooklyn CSP', 'Stonington PD', 'Stamford PD...  dataset
# 4431                                                 []      map
# 4439                                                 []     href
# 4451          ['YEAR', 'TOTAL', 'LICENSE ENDOSREMENTS']    chart
# 4478  ['Cases Closed', 'Year', 'Month', 'Cases Open'...  dataset
# 4524  ['Urban', 'Tolland County', 'W.C.S.U.', 'S.C.S...  dataset
# 4528  ['Murder Relationship Live-In, Male', 'Murder ...  dataset
# 4529                                                 []      map
# 4539                                                 []      map
# 4812  ['CATEGORY', 'ROWNUM', 'HOUR', 'LOCATION', 'CE...  dataset
# 4828  ['Y', 'X', 'STATE', 'DAY', 'FID', 'REPORT_NO',...  dataset
# 4839                                                 []      map
# 4859  ['STATE', 'DAY', 'Location_1', 'PRECINCT', 'FI...  dataset
# 4867  ['Y', 'STATE', 'DAY', 'Location_1', 'TIME', 'R...  dataset
# 4871  ['DAY', 'DATE', 'FID', 'PRECINCT', 'REPORT_NO'...  dataset
# 4873                                                 []      map
# 4875  ['CITY', 'FID', 'X', 'STATE', 'PRECINCT', 'DAT...  dataset
# 4880                                                 []      map
# 4889                                                 []      map
#
#                                  categories  \
# 21                                       []
# 22                                       []
# 88                                       []
# 101                                      []
# 160                                      []
# 161                                      []
# 231                                      []
# 239                                      []
# 252                                      []
# 272                                      []
# 275                                      []
# 286                                      []
# 316                                      []
# 340                                      []
# 358                       ['public safety']
# 394                                      []
# 431                                      []
# 437                                      []
# 444                                      []
# 459                                      []
# 503                                      []
# 517                                      []
# 523                                      []
# 534                                      []
# 568             ['public safety', 'health']
# 575             ['public safety', 'health']
# 583             ['public safety', 'health']
# 614                                      []
# 632                                      []
# 655                              ['health']
# ...                                     ...
# 4262            ['public safety', 'health']
# 4286                      ['public safety']
# 4287                                     []
# 4290            ['public safety', 'health']
# 4292            ['public safety', 'health']
# 4294                      ['public safety']
# 4302                                     []
# 4329            ['public safety', 'health']
# 4362           ['economy', 'public safety']
# 4388           ['economy', 'public safety']
# 4399            ['public safety', 'health']
# 4407            ['public safety', 'health']
# 4431                                     []
# 4439  ['transportation', 'social services']
# 4451           ['economy', 'public safety']
# 4478                      ['public safety']
# 4524                      ['public safety']
# 4528            ['public safety', 'health']
# 4529    ['infrastructure', 'public safety']
# 4539    ['infrastructure', 'public safety']
# 4812                      ['public safety']
# 4828                                     []
# 4839                                     []
# 4859                                     []
# 4867                                     []
# 4871                                     []
# 4873                                     []
# 4875                                     []
# 4880                                     []
# 4889                                     []
#
#                                         domain_category  \
# 21                                                  NaN
# 22                                                  NaN
# 88                                                  NaN
# 101                                                 NaN
# 160                                                 NaN
# 161                                                 NaN
# 231                                                 NaN
# 239                                                 NaN
# 252                                                 NaN
# 272                                   Individual Rights
# 275                              Culture and Recreation
# 286                                     Social Services
# 316                                               Other
# 340                                       Public Safety
# 358                                                 NaN
# 394                                                 NaN
# 431                                   Individual Rights
# 437                                       Public Safety
# 444                                       Public Safety
# 459   A New Day for: Safety Net, Homelessness, Publi...
# 503                                     Social Services
# 517   A New Day for: Safety Net, Homelessness, Publi...
# 523                                                 NaN
# 534                                               Other
# 568                                                 NaN
# 575                                                 NaN
# 583                                                 NaN
# 614                                                 NaN
# 632                                                 NaN
# 655                                       Public Safety
# ...                                                 ...
# 4262                                      Public Safety
# 4286                                      Public Safety
# 4287                                      Public Safety
# 4290                                      Public Safety
# 4292                                      Public Safety
# 4294                                      Public Safety
# 4302                                      Public Safety
# 4329                                      Public Safety
# 4362                                     Transportation
# 4388                                     Transportation
# 4399                                      Public Safety
# 4407                                      Public Safety
# 4431                                      Public Safety
# 4439                                     Transportation
# 4451                                     Transportation
# 4478                                     Transportation
# 4524                                      Public Safety
# 4528                                      Public Safety
# 4529                                                NaN
# 4539                                                NaN
# 4812                                      Public Safety
# 4828                                      Public Safety
# 4839                                      Public Safety
# 4859                                      Public Safety
# 4867                                      Public Safety
# 4871                                      Public Safety
# 4873                                      Public Safety
# 4875                                      Public Safety
# 4880                                      Public Safety
# 4889                                      Public Safety
#
#                                             domain_tags provenance  \
# 21    ['sexual assault', 'domestic violence', 'safet...   official
# 22    ['sexual assault', 'domestic violence', 'safet...   official
# 88                       ['safety', 'sa', 'dv', 'dchs']   official
# 101   ['sexual assault', 'domestic violence', 'safet...   official
# 160   ['sexual assault', 'domestic violence', 'safet...   official
# 161   ['sexual assault', 'domestic violence', 'safet...   official
# 231   ['sexual assault', 'domestic violence', 'safet...   official
# 239                      ['safety', 'sa', 'dv', 'dchs']   official
# 252                      ['safety', 'sa', 'dv', 'dchs']   official
# 272                         ['baseline', 'land', 'oha']   official
# 275           ['culture', 'hawaiian', 'history', 'oha']   official
# 286          ['hawaiian', 'homeless', 'housing', 'oha']   official
# 316   ['hawaiian', 'oha', 'population', 'race', 'sta...   official
# 340                                                  []   official
# 358                                                  []   official
# 394                                             ['oha']   official
# 431                         ['baseline', 'land', 'oha']   official
# 437                                                  []   official
# 444                                                  []   official
# 459                                                  []   official
# 503          ['hawaiian', 'homeless', 'housing', 'oha']   official
# 517                                                  []   official
# 523                                             ['oha']   official
# 534   ['hawaiian', 'oha', 'population', 'race', 'sta...   official
# 568                                                  []   official
# 575                                                  []   official
# 583                                                  []   official
# 614      ['index crime', 'crime rate', 'rate', 'crime']   official
# 632              ['crime rate', 'index crimes', 'utah']   official
# 655                                                  []   official
# ...                                                 ...        ...
# 4262                       ['offenses', 'crime', 'ucr']   official
# 4286                        ['arrests', 'crime', 'ucr']   official
# 4287  ['crime', 'departments', 'police', 'public saf...   official
# 4290                       ['offenses', 'crime', 'ucr']   official
# 4292               ['2013', 'offenses', 'crime', 'ucr']   official
# 4294                        ['arrests', 'crime', 'ucr']   official
# 4302           ['public safety', 'personnel', 'police']   official
# 4329                       ['offenses', 'crime', 'ucr']   official
# 4362                                            ['dmv']   official
# 4388                                            ['dmv']   official
# 4399                       ['offenses', 'crime', 'ucr']   official
# 4407                       ['crime', 'offenses', 'ucr']   official
# 4431  ['police', 'law enforcement', 'new haven', 'nhv']   official
# 4439    ['accidents', 'crash', 'usodcensus', 'vehicle']   official
# 4451                                            ['dmv']   official
# 4478                                            ['dmv']   official
# 4524                        ['arrests', 'crime', 'ucr']   official
# 4528                       ['offenses', 'crime', 'ucr']   official
# 4529                                                 []   official
# 4539                                                 []   official
# 4812            ['crime', 'detroit police', 'offenses']   official
# 4828             ['victim-based', 'homicide', 'police']   official
# 4839                     ['police', 'dpd', 'precincts']   official
# 4859   ['victim-based', 'non-fatal shooting', 'police']   official
# 4867           ['victim-based', 'carjacking', 'police']   official
# 4871     ['2014', 'victim-based', 'homicide', 'police']   official
# 4873             ['victim-based', 'homicide', 'police']   official
# 4875   ['victim-based', 'non-fatal shooting', 'police']   official
# 4880           ['victim-based', 'carjacking', 'police']   official
# 4889   ['victim-based', 'non-fatal shooting', 'police']   official
#
#       download_count  page_views_last_month  page_views_last_week  \
# 21             6.000                 27.000                 0.000
# 22             4.000                 18.000                 0.000
# 88             3.000                  9.000                 1.000
# 101           11.000                  8.000                 0.000
# 160            0.000                  0.000                 0.000
# 161            1.000                  0.000                 0.000
# 231            0.000                  0.000                 0.000
# 239            2.000                  0.000                 0.000
# 252            0.000                  0.000                 0.000
# 272           90.000                118.000                23.000
# 275           51.000                 24.000                 3.000
# 286           34.000                 30.000                 3.000
# 316           47.000                 21.000                 4.000
# 340           21.000                 21.000                 0.000
# 358           17.000                 45.000                 6.000
# 394           49.000                  1.000                 0.000
# 431           51.000                  0.000                 0.000
# 437           17.000                  0.000                 0.000
# 444           26.000                  2.000                 0.000
# 459           17.000                  0.000                 0.000
# 503           22.000                  0.000                 0.000
# 517           24.000                  0.000                 0.000
# 523           28.000                  1.000                 0.000
# 534           24.000                  1.000                 0.000
# 568           38.000                  0.000                 0.000
# 575           33.000                  4.000                 1.000
# 583           25.000                  0.000                 0.000
# 614          602.000                  7.000                 1.000
# 632          583.000                  5.000                 0.000
# 655         1111.000               1395.000               310.000
# ...              ...                    ...                   ...
# 4262         738.000                  0.000                 0.000
# 4286         580.000                  0.000                 0.000
# 4287         878.000                  9.000                 8.000
# 4290         674.000                  5.000                 2.000
# 4292         577.000                  2.000                 0.000
# 4294         553.000                  6.000                 1.000
# 4302         584.000                  1.000                 0.000
# 4329         702.000                  9.000                 3.000
# 4362          77.000                 13.000                 1.000
# 4388          69.000                 14.000                 2.000
# 4399         661.000                  1.000                 0.000
# 4407         644.000                  5.000                 0.000
# 4431         365.000                 17.000                 6.000
# 4439          36.000                 12.000                 2.000
# 4451          35.000                  4.000                 1.000
# 4478         649.000                  7.000                 4.000
# 4524         327.000                 14.000                 5.000
# 4528         369.000                 11.000                 4.000
# 4529          15.000                 10.000                 0.000
# 4539          17.000                  5.000                 0.000
# 4812         534.000                118.000                17.000
# 4828         197.000                 66.000                19.000
# 4839         992.000                 35.000                11.000
# 4859          99.000                 19.000                 5.000
# 4867         103.000                 18.000                 7.000
# 4871          92.000                  6.000                 2.000
# 4873          84.000                 15.000                 5.000
# 4875          80.000                  8.000                 0.000
# 4880          48.000                  8.000                 2.000
# 4889          60.000                  8.000                 2.000
#
#       page_views_total  page_views_total_log                      domain  \
# 21             190.000                 7.577  dashboard.alexandriava.gov
# 22             189.000                 7.570  dashboard.alexandriava.gov
# 88              67.000                 6.087  dashboard.alexandriava.gov
# 101             58.000                 5.883  dashboard.alexandriava.gov
# 160             29.000                 4.907  dashboard.alexandriava.gov
# 161             29.000                 4.907  dashboard.alexandriava.gov
# 231             10.000                 3.459  dashboard.alexandriava.gov
# 239              9.000                 3.322  dashboard.alexandriava.gov
# 252              7.000                 3.000  dashboard.alexandriava.gov
# 272           9494.000                13.213        dashboard.hawaii.gov
# 275           4640.000                12.180        dashboard.hawaii.gov
# 286            344.000                 8.430        dashboard.hawaii.gov
# 316            257.000                 8.011        dashboard.hawaii.gov
# 340            219.000                 7.781        dashboard.hawaii.gov
# 358            201.000                 7.658        dashboard.hawaii.gov
# 394            170.000                 7.418        dashboard.hawaii.gov
# 431            148.000                 7.219        dashboard.hawaii.gov
# 437            146.000                 7.200        dashboard.hawaii.gov
# 444            143.000                 7.170        dashboard.hawaii.gov
# 459            136.000                 7.098        dashboard.hawaii.gov
# 503            120.000                 6.919        dashboard.hawaii.gov
# 517            117.000                 6.883        dashboard.hawaii.gov
# 523            113.000                 6.833        dashboard.hawaii.gov
# 534            109.000                 6.781        dashboard.hawaii.gov
# 568            142.000                 7.160         dashboard.plano.gov
# 575            108.000                 6.768         dashboard.plano.gov
# 583             99.000                 6.644         dashboard.plano.gov
# 614          27150.000                14.729          dashboard.slco.org
# 632          26585.000                14.698          dashboard.slco.org
# 655          20065.000                14.292              data.acgov.org
# ...                ...                   ...                         ...
# 4262           494.000                 8.951                 data.ct.gov
# 4286           453.000                 8.827                 data.ct.gov
# 4287           453.000                 8.827                 data.ct.gov
# 4290           450.000                 8.817                 data.ct.gov
# 4292           446.000                 8.804                 data.ct.gov
# 4294           445.000                 8.801                 data.ct.gov
# 4302           433.000                 8.762                 data.ct.gov
# 4329           381.000                 8.577                 data.ct.gov
# 4362           329.000                 8.366                 data.ct.gov
# 4388           291.000                 8.190                 data.ct.gov
# 4399           278.000                 8.124                 data.ct.gov
# 4407           268.000                 8.071                 data.ct.gov
# 4431           230.000                 7.852                 data.ct.gov
# 4439           223.000                 7.807                 data.ct.gov
# 4451           210.000                 7.721                 data.ct.gov
# 4478           147.000                 7.209                 data.ct.gov
# 4524            59.000                 5.907                 data.ct.gov
# 4528            55.000                 5.807                 data.ct.gov
# 4529            54.000                 5.781                 data.ct.gov
# 4539            45.000                 5.524                 data.ct.gov
# 4812          5440.000                12.410          data.detroitmi.gov
# 4828          1559.000                10.607          data.detroitmi.gov
# 4839          1078.000                10.075          data.detroitmi.gov
# 4859           666.000                 9.382          data.detroitmi.gov
# 4867           532.000                 9.058          data.detroitmi.gov
# 4871           474.000                 8.892          data.detroitmi.gov
# 4873           455.000                 8.833          data.detroitmi.gov
# 4875           432.000                 8.758          data.detroitmi.gov
# 4880           359.000                 8.492          data.detroitmi.gov
# 4889           243.000                 7.931          data.detroitmi.gov
#
#                                                    mash  \
# 21    ['sexual', 'assault', 'domestic', 'violence', ...
# 22    ['sexual', 'assault', 'domestic', 'violence', ...
# 88                       ['safety', 'sa', 'dv', 'dchs']
# 101   ['sexual', 'assault', 'domestic', 'violence', ...
# 160   ['sexual', 'assault', 'domestic', 'violence', ...
# 161   ['sexual', 'assault', 'domestic', 'violence', ...
# 231   ['sexual', 'assault', 'domestic', 'violence', ...
# 239                      ['safety', 'sa', 'dv', 'dchs']
# 252                      ['safety', 'sa', 'dv', 'dchs']
# 272   ['baseline', 'land', 'oha', 'individual', 'rig...
# 275   ['culture', 'hawaiian', 'history', 'oha', 'cul...
# 286   ['hawaiian', 'homeless', 'housing', 'oha', 'so...
# 316   ['hawaiian', 'oha', 'population', 'race', 'sta...
# 340                                ['public', 'safety']
# 358                                ['public', 'safety']
# 394                                             ['oha']
# 431   ['baseline', 'land', 'oha', 'individual', 'rig...
# 437                                ['public', 'safety']
# 444                                ['public', 'safety']
# 459   ['a', 'new', 'day', 'for:', 'safety', 'net', '...
# 503   ['hawaiian', 'homeless', 'housing', 'oha', 'so...
# 517   ['a', 'new', 'day', 'for:', 'safety', 'net', '...
# 523                                             ['oha']
# 534   ['hawaiian', 'oha', 'population', 'race', 'sta...
# 568                      ['public', 'safety', 'health']
# 575                      ['public', 'safety', 'health']
# 583                      ['public', 'safety', 'health']
# 614   ['index', 'crime', 'crime', 'rate', 'rate', 'c...
# 632        ['crime', 'rate', 'index', 'crimes', 'utah']
# 655                      ['health', 'public', 'safety']
# ...                                                 ...
# 4262  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4286  ['arrests', 'crime', 'ucr', 'public', 'safety'...
# 4287  ['crime', 'departments', 'police', 'public', '...
# 4290  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4292  ['2013', 'offenses', 'crime', 'ucr', 'public',...
# 4294  ['arrests', 'crime', 'ucr', 'public', 'safety'...
# 4302  ['public', 'safety', 'personnel', 'police', 'p...
# 4329  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4362  ['dmv', 'economy', 'public', 'safety', 'transp...
# 4388  ['dmv', 'economy', 'public', 'safety', 'transp...
# 4399  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4407  ['crime', 'offenses', 'ucr', 'public', 'safety...
# 4431  ['police', 'law', 'enforcement', 'new', 'haven...
# 4439  ['accidents', 'crash', 'usodcensus', 'vehicle'...
# 4451  ['dmv', 'economy', 'public', 'safety', 'transp...
# 4478      ['dmv', 'public', 'safety', 'transportation']
# 4524  ['arrests', 'crime', 'ucr', 'public', 'safety'...
# 4528  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4529             ['infrastructure', 'public', 'safety']
# 4539             ['infrastructure', 'public', 'safety']
# 4812  ['crime', 'detroit', 'police', 'offenses', 'pu...
# 4828  ['victim-based', 'homicide', 'police', 'public...
# 4839  ['police', 'dpd', 'precincts', 'public', 'safe...
# 4859  ['victim-based', 'non-fatal', 'shooting', 'pol...
# 4867  ['victim-based', 'carjacking', 'police', 'publ...
# 4871  ['2014', 'victim-based', 'homicide', 'police',...
# 4873  ['victim-based', 'homicide', 'police', 'public...
# 4875  ['victim-based', 'non-fatal', 'shooting', 'pol...
# 4880  ['victim-based', 'carjacking', 'police', 'publ...
# 4889  ['victim-based', 'non-fatal', 'shooting', 'pol...
#
#                                                big_mash  \
# 21    ['sexual', 'assault', 'domestic', 'violence', ...
# 22    ['sexual', 'assault', 'domestic', 'violence', ...
# 88                       ['safety', 'sa', 'dv', 'dchs']
# 101   ['sexual', 'assault', 'domestic', 'violence', ...
# 160   ['sexual', 'assault', 'domestic', 'violence', ...
# 161   ['sexual', 'assault', 'domestic', 'violence', ...
# 231   ['sexual', 'assault', 'domestic', 'violence', ...
# 239                      ['safety', 'sa', 'dv', 'dchs']
# 252                      ['safety', 'sa', 'dv', 'dchs']
# 272   ['baseline', 'land', 'oha', 'individual', 'rig...
# 275   ['culture', 'hawaiian', 'history', 'oha', 'cul...
# 286   ['hawaiian', 'homeless', 'housing', 'oha', 'so...
# 316   ['hawaiian', 'oha', 'population', 'race', 'sta...
# 340   ['public', 'safety', 'Includes', 'decibel', 'l...
# 358                                ['public', 'safety']
# 394                                             ['oha']
# 431   ['baseline', 'land', 'oha', 'individual', 'rig...
# 437                                ['public', 'safety']
# 444   ['public', 'safety', 'Includes', 'decibel', 'l...
# 459   ['a', 'new', 'day', 'for:', 'safety', 'net', '...
# 503   ['hawaiian', 'homeless', 'housing', 'oha', 'so...
# 517   ['a', 'new', 'day', 'for:', 'safety', 'net', '...
# 523                                             ['oha']
# 534   ['hawaiian', 'oha', 'population', 'race', 'sta...
# 568                      ['public', 'safety', 'health']
# 575                      ['public', 'safety', 'health']
# 583                      ['public', 'safety', 'health']
# 614   ['index', 'crime', 'crime', 'rate', 'rate', 'c...
# 632   ['crime', 'rate', 'index', 'crimes', 'utah', '...
# 655   ['health', 'public', 'safety', 'Alameda', 'Cou...
# ...                                                 ...
# 4262  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4286  ['arrests', 'crime', 'ucr', 'public', 'safety'...
# 4287  ['crime', 'departments', 'police', 'public', '...
# 4290  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4292  ['2013', 'offenses', 'crime', 'ucr', 'public',...
# 4294  ['arrests', 'crime', 'ucr', 'public', 'safety'...
# 4302  ['public', 'safety', 'personnel', 'police', 'p...
# 4329  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4362  ['dmv', 'economy', 'public', 'safety', 'transp...
# 4388  ['dmv', 'economy', 'public', 'safety', 'transp...
# 4399  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4407  ['crime', 'offenses', 'ucr', 'public', 'safety...
# 4431  ['police', 'law', 'enforcement', 'new', 'haven...
# 4439  ['accidents', 'crash', 'usodcensus', 'vehicle'...
# 4451  ['dmv', 'economy', 'public', 'safety', 'transp...
# 4478  ['dmv', 'public', 'safety', 'transportation', ...
# 4524  ['arrests', 'crime', 'ucr', 'public', 'safety'...
# 4528  ['offenses', 'crime', 'ucr', 'public', 'safety...
# 4529  ['infrastructure', 'public', 'safety', 'Connec...
# 4539  ['infrastructure', 'public', 'safety', 'Connec...
# 4812  ['crime', 'detroit', 'police', 'offenses', 'pu...
# 4828  ['victim-based', 'homicide', 'police', 'public...
# 4839  ['police', 'dpd', 'precincts', 'public', 'safe...
# 4859  ['victim-based', 'non-fatal', 'shooting', 'pol...
# 4867  ['victim-based', 'carjacking', 'police', 'publ...
# 4871  ['2014', 'victim-based', 'homicide', 'police',...
# 4873  ['victim-based', 'homicide', 'police', 'public...
# 4875  ['victim-based', 'non-fatal', 'shooting', 'pol...
# 4880  ['victim-based', 'carjacking', 'police', 'publ...
# 4889  ['victim-based', 'non-fatal', 'shooting', 'pol...
#
#                                              topic_comp
# 21    [(16, 0.1616786051), (26, 0.431318681319), (50...
# 22    [(16, 0.161766956351), (26, 0.431318681319), (...
# 88    [(16, 0.203846153846), (26, 0.403846153846), (...
# 101   [(16, 0.162007823798), (26, 0.431318681319), (...
# 160   [(16, 0.161854234981), (26, 0.431318681319), (...
# 161   [(16, 0.161685334512), (26, 0.431318681319), (...
# 231   [(16, 0.161934869861), (26, 0.431318681319), (...
# 239   [(16, 0.203846153846), (26, 0.403846153846), (...
# 252   [(16, 0.203846153846), (26, 0.403846153846), (...
# 272   [(4, 0.0445430353893), (9, 0.13570023278), (21...
# 275   [(1, 0.137036692987), (5, 0.188701923077), (6,...
# 286   [(17, 0.145604395604), (18, 0.145604395604), (...
# 316   [(2, 0.169871794872), (26, 0.503205128204), (4...
# 340          [(5, 0.33547008547), (26, 0.557692307692)]
# 358                              [(26, 0.673076923077)]
# 394                              [(26, 0.509615384615)]
# 431   [(4, 0.0444289989737), (9, 0.13576160706), (21...
# 437                              [(26, 0.673076923077)]
# 444          [(5, 0.33547008547), (26, 0.557692307692)]
# 459   [(26, 0.33547008547), (29, 0.113247863248), (4...
# 503   [(17, 0.145604395604), (18, 0.145604395604), (...
# 517   [(26, 0.33547008547), (29, 0.113247863248), (4...
# 523                              [(26, 0.509615384615)]
# 534   [(2, 0.169871794872), (26, 0.503205128205), (4...
# 568         [(2, 0.254807692308), (26, 0.504807692308)]
# 575         [(2, 0.254807692308), (26, 0.504807692308)]
# 583         [(2, 0.254807692308), (26, 0.504807692308)]
# 614   [(0, 0.0728021978022), (2, 0.135665761033), (7...
# 632   [(2, 0.0849358974359), (7, 0.168269230769), (2...
# 655   [(2, 0.131321120447), (23, 0.106439139191), (2...
# ...                                                 ...
# 4262  [(5, 0.0630686980655), (8, 0.0202852809573), (...
# 4286  [(9, 0.101876589899), (23, 0.0512549258423), (...
# 4287  [(25, 0.0533695146241), (26, 0.374136972605), ...
# 4290  [(5, 0.0630712893518), (8, 0.020285294677), (1...
# 4292  [(5, 0.0630705946552), (8, 0.0202853012731), (...
# 4294  [(9, 0.101877187909), (23, 0.0512551214156), (...
# 4302  [(15, 0.179307951581), (16, 0.0578863990146), ...
# 4329  [(5, 0.0630710354293), (8, 0.0202852968573), (...
# 4362  [(2, 0.169871794872), (3, 0.169871794872), (16...
# 4388  [(2, 0.169871794872), (3, 0.169871794872), (16...
# 4399  [(5, 0.0630705851969), (8, 0.0202852865935), (...
# 4407  [(5, 0.0630721336619), (8, 0.0202853058285), (...
# 4431  [(5, 0.0784023668639), (26, 0.539940828397), (...
# 4439  [(3, 0.0701899402726), (7, 0.0131257766537), (...
# 4451  [(2, 0.169871794872), (3, 0.169871794872), (16...
# 4478  [(2, 0.0926573426573), (3, 0.0926573426573), (...
# 4524  [(2, 0.0674580972245), (8, 0.0351770567299), (...
# 4528  [(5, 0.0630711277688), (8, 0.0202853015264), (...
# 4529  [(1, 0.0104482683654), (2, 0.0100505055654), (...
# 4539  [(2, 0.0458611394719), (3, 0.0111117542859), (...
# 4812  [(8, 0.0613390263294), (20, 0.0599547511312), ...
# 4828  [(4, 0.235396672376), (23, 0.110301885217), (2...
# 4839  [(23, 0.213674846029), (26, 0.331946920678), (...
# 4859  [(4, 0.208449561457), (14, 0.0478343078921), (...
# 4867  [(4, 0.239361338926), (22, 0.0441467380176), (...
# 4871  [(4, 0.235266934147), (23, 0.110335410239), (2...
# 4873  [(4, 0.235313755179), (23, 0.110276662358), (2...
# 4875  [(4, 0.208435187859), (14, 0.0478343282382), (...
# 4880  [(4, 0.239419303997), (22, 0.0441419106655), (...
# 4889  [(4, 0.208349233919), (14, 0.0478344892368), (...
#
# [200 rows x 20 columns]

# %% [markdown]
# # Conclusions:
# **How you count "popularity" matters.**
# - Nevertheless, **transportation and crime/public safety dataset popularity is resilient** across different measures of popularity that we've defined.
#
# **When you "dampen" the effects of cities/states whose open data portals get a high volume of traffic, popularity rankings change somewhat**.
# - This suggests that "popularity" (as we've defined it) in very large and/or populated areas is different than other areas.
# - This may be because of a genuine difference in citizen preference, a difference in what data these governments choose to display prominently (everyone care about traffic, but California *really* cares about traffic), or a skew from users across the country and world accessing this data (NYC, for instance, is a popular domain for datasets for data science research projects).
#
# **We argue that "dampened" popularity is the most appropriate metric for wide applicability to a variety of government organizations**.
#  - It appears to truly reduce the influence of large CA, NYC, and TX datasets. Not that there's anything wrong with these places or portals! But we want this information to be useful to smaller cities as well.
#  - **Using dampened popularity, the following topics show notable popularity:**
#     - Crime Reports and Public Safety Response
#     - Personal Transportation and Traffic
#     - Community Economic Development & Housing
#     - Business Licensing
#     - Project Permitting and Financing
#
# **Popularity is *always* going to be affected by what a city or state chooses to display prominently on its web portal.**
# - For example -- using our old metric of popularity, ‘energy environment electricity air sustainable action climate city clean facilities’ was the most popular topic in Providence, RI. Providence, RI displays a link to sustainability info right on its front page. It is hard to tell what is cause and what is effect.
# - **This is not a controlled experiment. We hope that a sample of 141 open data portals controls enough for individual variation in what datasets are easiest for users to access in a given portal**.
#
# **No meta analysis alone can tell a city what kind of open data will be most popular, let alone most urgent to the public interest.**
# - As we saw from our undampened popularity measures, cities have a variety of most popular topics. This is influenced by both local preference and local decisions about what datasets to display prominently.
# - Just because a dataset is popular doesn't mean it serves the most urgent or broadest public purpose.
#     - Open data users are not a cross section of voters or the general public. Permitting information is important and useful for developers. It should be open and accessible for concerned citizens as well. But other types of information may be more useful to the average citizen.
#
# **These results are only applicable to domains hosted by Socrata. We'd expect that a wider range of cities/states wouldn't alter results that much, but we can't be sure.**

# %% [markdown]
# ## Caveats
# ### Errors, uncertainty, and additional notes:
# **Again, not every dataset is tagged thoroughy, accurately, or appropriately.**
#   - Some cities/portals just give their datasets weird names or use stock descriptions for every single category of open data. That's why we've formed a bland or vague topic or two.
#
# **Proper names obviously skew results somewhat; a proper name doesn't really tell us about the content of a dataset.**
#   - However, it's just not feasible to remove every proper name as a stopword; at least not without extensive trial and error
#   - "Dampened Popularity" best avoids this effect by requiring a cut off (0.2), only counting "winning" topics, and normalizing popularity scores *within* a city.
#
# **We are only displaying the top 10 words by affinity for each topic. The topics go much deeper, picking up some marginal affinity from words that may not make as much sense to the human eye.**
#    - This is also a weakness of our model. Real life, human eye topics are of varying length in terms of words. But our model forms topics of equal sizes.
#
# **Why not KMeans or some other form of clustering to group datasets?**
# - Those with strong backgrounds in data science may ask why we didn't turn each dataset's "mash" into a tf-idf vector and then "cluster" datasets based on their distance in mathematical space. We tried! However, the data formed by the tf-idf vectorizer was too sparse. KMeans' explicit number of clusters forced dissimilar datasets together too often. DBSCAN's ability to create clusters of varying density and assign data points to an 'outlier' cluster produced highly specific clusters that didn't cut across cities as much as we'd like. And too often a DBSCAN assigned over half of our datasets to an outlier category.
# - **We'd encourage those with strong backgrounds in data science and machine learning to take a cut at this. It's possible clustering could still produce useful formations, and it would be a more stable formation our rather reverse process using LDA topic modeling.**
#
# **The human brain interprets our clusters at the end. It's up to us to determine what our "topic" should really be named in human English. Two LDA topics may be very similar real-life topics (we can see this with our two transportation datasets - probably because that's such a prevalent real-life category).**
#   - Then again, all of this is labeled by humans. Back to our first point, there is always room for disagreement/debate in what "subject" a dataset is about, and how narrow to make subjects.
